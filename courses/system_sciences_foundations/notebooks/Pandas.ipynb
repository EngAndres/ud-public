# %% [markdown]
# # PANDAS
#
# __Pandas__ is a powerful _open-source_ data manipulation and analysis library for _Python_.
#
# It provides data structures and functions for efficiently __handling and analyzing structured data__, such as tables or spreadsheets.
#
# With __pandas__, you can easily _load_, _manipulate_, _analyze data_, perform _data cleaning_ and _preprocessing_ tasks, and create _visualizations_.
#
# It is widely used in _data science_, _machine learning_, and _data analysis_ projects.
#
# To import the pandas library and assigns it the alias 'pd', you could make `import pandas as pd`.

# %% [markdown]
# ## The Series Data Structure
#
# A __pandas Series__ is a _one-dimensional labeled array_ capable of holding any data type. It is similar to a _column_ in a spreadsheet or a SQL table, or a _dictionary-like_ object. It is a fundamental _data structure_ in __pandas__ library, which is widely used for data manipulation and analysis in Python.
#
# A __pandas Series__ consists of two main components: the _data_ and the _index_. The _data_ can be of any type, such as integers, floats, strings, or even complex objects. The _index_ is a sequence of labels that uniquely identifies each element in the Series.
#
# Some key features of pandas Series include:
# - Vectorized operations: Series supports vectorized operations, allowing you to perform element-wise computations efficiently.
# - Label-based indexing: You can access elements in a Series using labels instead of integer-based indexing.
# - Alignment: Series automatically aligns data based on the index, making it easy to perform operations on multiple Series with different indexes.
#
# To create a __Series__, you can pass a list, array, or dictionary-like object to the `pd.Series()` constructor. You can also specify custom index labels if needed.

# %%
import pandas as pd

# Create a Series object from a list of strings
list_strings = ['a', 'b', 'c', 'd', 'e']
serie_1 = pd.Series(list_strings)
print("Serie 1:", serie_1)

# Create a Series object from a list of numbers
list_numbers = [1, 2, 3, 4, 5]
serie_2 = pd.Series(list_numbers)
print("Serie 2:", serie_2)

# Create a Series object from a list of numbers with a None value
list_numbers_with_none = [1, 2, None, 4, 5]
serie_3 = pd.Series(list_numbers_with_none)
print("Serie 3:", serie_3)
# Out:
# Serie 1: 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object
# Serie 2: 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# Serie 3: 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# dtype: float64

# %%
# Create a Series object from a dictionary
dict_data = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
serie_4 = pd.Series(dict_data)
print("Serie 4:", serie_4)

# Get the values of the Series index
print("Serie 4 index:", serie_4.index)
# Out:
# Serie 4: a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# Serie 4 index: Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
# Create a series object from a list of tuple pairs
list_tuples = [('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e', 5)]
serie_5 = pd.Series(list_tuples)
print("Serie 5:", serie_5)
# Out:
# Serie 5: 0    (a, 1)
# 1    (b, 2)
# 2    (c, 3)
# 3    (d, 4)
# 4    (e, 5)
# dtype: object

# %%
# Create a series object from a list as values and a list as index
list_index = ['a', 'b', 'c', 'd', 'e']
list_values = [1, 2, 3, 4, 5]
serie_6 = pd.Series(list_values, index=list_index)
print("Serie 6:\n", serie_6)

for index, value in serie_6.items():
    print(f"Index: {index}, Value: {value}")
# Out:
# Serie 6:
#  a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# Index: a, Value: 1
# Index: b, Value: 2
# Index: c, Value: 3
# Index: d, Value: 4
# Index: e, Value: 5

# %%
# Query a Series object by boolean indexing
print("Serie 6 > 2:", serie_6[serie_6 > 2])
print("-"*10)
print(serie_6 > 2)
# Out:
# Serie 6 > 2: c    3
# d    4
# e    5
# dtype: int64
# ----------
# a    False
# b    False
# c     True
# d     True
# e     True
# dtype: bool

# %%
# Query a Series object by faccy indexing
print("Serie 6[['a', 'b']]:", serie_6[['a', 'b']])
# Out:
# Serie 6[['a', 'b']]: a    1
# b    2
# dtype: int64

# %%
# Query a Series object using loc[]
print("Serie 6.loc[['a', 'b']]:", serie_6.loc[['a', 'b']])
# Out:
# Serie 6.loc[['a', 'b']]: a    1
# b    2
# dtype: int64

# %%
# Query a Series object using iloc[]
print("Serie 6.iloc[0:3]:", serie_6.iloc[0:3])
# Out:
# Serie 6.iloc[0:3]: a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# ## The DataFrame Data Structure
#
# A __pandas DataFrame__ is a _two-dimensional_, _labeled_ data structure in _Python_ that is commonly used for _data manipulation and analysis_. It consists of _rows_ and _columns_, similar to a table in a relational database.
#
# The __DataFrame__ can store _heterogeneous data types_ and provides various operations and functions to perform data manipulation, filtering, grouping, and statistical analysis.
#
# To access and manipulate the data in the __DataFrame__, you can use various _methods_ and _attributes_ provided by the __pandas__ library.
#
# For more information on __pandas DataFrame__, refer to the [official pandas documentation](https://pandas.pydata.org/docs/reference/frame.html).

# %%
# create dataframes from lists
list_example = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
df = pd.DataFrame(list_example)
print("Dataframe from list:", df)
print("Dataframe from list shape:", df.shape)
print("Dataframe from list columns:", df.columns)
print("Dataframe from list index:", df.index)
# Out:
# Dataframe from list:    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9
# Dataframe from list shape: (3, 3)
# Dataframe from list columns: RangeIndex(start=0, stop=3, step=1)
# Dataframe from list index: RangeIndex(start=0, stop=3, step=1)

# %%
# create a dataframe from a list of dictionaries
list_dict = [{'a': 1, 'b': 2, 'c': 3}, {'a': 4, 'b': 5, 'c': 6}, {'a': 7, 'b': 8, 'c': 9}]
df = pd.DataFrame(list_dict)
print("Dataframe from list of dictionaries:", df)
print("Dataframe from list columns:", df.columns)
print("Dataframe from list index:", df.index)
# Out:
# Dataframe from list of dictionaries:    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9
# Dataframe from list columns: Index(['a', 'b', 'c'], dtype='object')
# Dataframe from list index: RangeIndex(start=0, stop=3, step=1)

# %%
# create a dataframe from a csv file
df_csv = pd.read_csv('csv-files/StudentsInfo.csv')
print(df_csv.head())
# Out:
#             Name                         Company                     Position  \
# 0  Alice Johnson  Hernandez, Griffith and Nelson           Petroleum engineer
# 1    David Jones                    Gomez-Garcia       Geologist, engineering
# 2      Eva Brown                     Blevins LLC               Microbiologist
# 3    Frank Davis                   Greene-Wilson     Museum education officer
# 4  Jack Anderson                      Butler PLC  Scientist, research (maths)
#
#    Salary
# 0    4740
# 1   73329
# 2   83245
# 3   74390
# 4   69851

# %%
# create a dataframe from a json file
df_json = pd.read_json('json-files/StudentsInfo.json')
print(df_json.head())
# Out:
#    id            name                  career                college
# 0   1   Alice Johnson        Computer Science        Tech University
# 1   2       Bob Smith  Mechanical Engineering  Engineering Institute
# 2   3  Carol Williams  Electrical Engineering        Tech University
# 3   4     David Jones                 Biology        Science College
# 4   5       Eva Brown                 Physics        Tech University

# %%
# describe a dataframe
print("Dataframe csv describe:\n", df_csv.describe())
print("*"*10)
print("Dataframe json describe:\n", df_json.describe())
# Out:
# Dataframe csv describe:
#               Salary
# count     30.000000
# mean   53491.600000
# std    27432.862783
# min     4740.000000
# 25%    27472.000000
# 50%    64104.000000
# 75%    72981.250000
# max    93995.000000
# **********
# Dataframe json describe:
#               id
# count  50.00000
# mean   25.50000
# std    14.57738
# min     1.00000
# 25%    13.25000
# 50%    25.50000
# 75%    37.75000
# max    50.00000

# %%
# get information about a dataframe
print("Dataframe csv info:\n", df_csv.info())
print("="*50)
print("Dataframe json info:\n", df_json.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      30 non-null     object
#  1   Company   30 non-null     object
#  2   Position  30 non-null     object
#  3   Salary    30 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB
# Dataframe csv info:
#  None
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       50 non-null     int64
#  1   name     50 non-null     object
#  2   career   50 non-null     object
#  3   college  50 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB
# Dataframe json info:
#  None

# %%
# indexes and columns
df_changed_index = df_csv.set_index('Name')
print("Dataframe csv changed index:\n", df_changed_index.head())
print("*"*50)
print("Dataframe csv changed index columns:\n", df_changed_index.columns)
print("Dataframe csv changed index index:\n", df_changed_index.index)
# Out:
# Dataframe csv changed index:
#                                        Company                     Position  \
# Name
# Alice Johnson  Hernandez, Griffith and Nelson           Petroleum engineer
# David Jones                      Gomez-Garcia       Geologist, engineering
# Eva Brown                         Blevins LLC               Microbiologist
# Frank Davis                     Greene-Wilson     Museum education officer
# Jack Anderson                      Butler PLC  Scientist, research (maths)
#
#                Salary
# Name
# Alice Johnson    4740
# David Jones     73329
# Eva Brown       83245
# Frank Davis     74390
# Jack Anderson   69851
# **************************************************
# Dataframe csv changed index columns:
#  Index(['Company', 'Position', 'Salary'], dtype='object')
# Dataframe csv changed index index:
#  Index(['Alice Johnson', 'David Jones', 'Eva Brown', 'Frank Davis',
#        'Jack Anderson', 'Kylie Thomas', 'Mia White', 'Noah Harris',
#        'Olivia Martin', 'Peyton Garcia', 'Quinn Robinson', 'Ryan Clark',
#        'Tyler Walker', 'Uma King', 'Victor Lee', 'Wendy Hall', 'Xavier Young',
#        'Yara Scott', 'Amy Campbell', 'Brian Mitchell', 'Elena Roberts',
#        'Felix Turner', 'Gina Phillips', 'Hugo Martinez', 'Leo Howard',
#        'Riley Green', 'Samantha Gonzalez', 'Travis Ward', 'Ulysses Simmons',
#        'Vivian Cook'],
#       dtype='object', name='Name')

# %%
# rename columns
df_renamed = df_csv.rename(columns={'Salary': 'Salary (USD/year)'})
df_renamed.head()
# Out:
#             Name                         Company                     Position  \
# 0  Alice Johnson  Hernandez, Griffith and Nelson           Petroleum engineer
# 1    David Jones                    Gomez-Garcia       Geologist, engineering
# 2      Eva Brown                     Blevins LLC               Microbiologist
# 3    Frank Davis                   Greene-Wilson     Museum education officer
# 4  Jack Anderson                      Butler PLC  Scientist, research (maths)
#
#    Salary (USD/year)
# 0               4740
# 1              73329
# 2              83245
# 3              74390
# 4              69851

# %% [markdown]
# ## Using Datetime into Pandas

# %%
# converting a column to datetime with to_datetime()
sales_df = pd.read_json('json-files/sales_data.json')
print("Sales dataframe:\n", sales_df.info())
print(sales_df[sales_df['code'] == "Sale-4594-TuGI"])
sales_df = sales_df.replace('2008-Dic-23', '2008-12-23')
print("*"*50)
sales_df['date'] = pd.to_datetime(sales_df['date'])
print("Sales dataframe with Date column as datetime:\n", sales_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         1000 non-null   object
#  1   client       1000 non-null   object
#  2   total_price  1000 non-null   float64
#  3   date         1000 non-null   object
#  4   hour         1000 non-null   object
#  5   credit_card  1000 non-null   int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 47.0+ KB
# Sales dataframe:
#  None
#               code         client  total_price         date      hour  \
# 24  Sale-4594-TuGI  Patrick Meyer       150.19  2008-Dic-23  07:32:54
#
#      credit_card
# 24  569507527095
# **************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         1000 non-null   object
#  1   client       1000 non-null   object
#  2   total_price  1000 non-null   float64
#  3   date         1000 non-null   datetime64[ns]
#  4   hour         1000 non-null   object
#  5   credit_card  1000 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 47.0+ KB
# Sales dataframe with Date column as datetime:
#  None

# %%
# converting a column from datetime to string with strftime()
sales_df['date_full'] = sales_df['date'].dt.strftime('%Y-%b-%d') + " " + sales_df['hour']
print(sales_df.head())
# Out:
#              code           client  total_price       date      hour  \
# 0  Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# 1  Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# 2  Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# 3  Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# 4  Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#         credit_card             date_full
# 0  6011811575065598  2024-Jun-03 08:13:18
# 1  6536303182814044  2014-Aug-22 02:57:20
# 2   213185615148626  1979-May-22 02:10:06
# 3  3558512811558836  1973-Dec-24 21:28:34
# 4  2239583806605394  1974-Mar-14 03:55:36

# %%
# converting a column from datetime to a timestamp with timestamp()
sales_df['timestamp'] = pd.to_datetime(sales_df['date_full']).apply(lambda x: x.timestamp())
print(sales_df.head())
sales_df['timestamp'] = sales_df['timestamp'].astype('int64')
print("="*50)
print(sales_df.head())
# Out:
#              code           client  total_price       date      hour  \
# 0  Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# 1  Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# 2  Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# 3  Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# 4  Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#         credit_card             date_full     timestamp
# 0  6011811575065598  2024-Jun-03 08:13:18  1.717402e+09
# 1  6536303182814044  2014-Aug-22 02:57:20  1.408676e+09
# 2   213185615148626  1979-May-22 02:10:06  2.961870e+08
# 3  3558512811558836  1973-Dec-24 21:28:34  1.256165e+08
# 4  2239583806605394  1974-Mar-14 03:55:36  1.324653e+08
# ==================================================
#              code           client  total_price       date      hour  \
# 0  Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# 1  Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# 2  Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# 3  Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# 4  Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#         credit_card             date_full   timestamp
# 0  6011811575065598  2024-Jun-03 08:13:18  1717402398
# 1  6536303182814044  2014-Aug-22 02:57:20  1408676240
# 2   213185615148626  1979-May-22 02:10:06   296187006
# 3  3558512811558836  1973-Dec-24 21:28:34   125616514
# 4  2239583806605394  1974-Mar-14 03:55:36   132465336

# %%
print(sales_df.describe())
# Out:
#        total_price                        date   credit_card     timestamp
# count  1000.000000                        1000  1.000000e+03  1.000000e+03
# mean    489.713800  1996-04-08 06:48:57.600000  3.550223e+17  8.289886e+08
# min      11.850000         1970-01-09 00:00:00  6.044392e+10  7.680400e+05
# 25%     226.677500         1982-09-14 06:00:00  1.800112e+14  4.008824e+08
# 50%     486.430000         1995-11-17 12:00:00  3.520377e+15  8.166286e+08
# 75%     732.752500         2009-05-24 06:00:00  4.632459e+15  1.243203e+09
# max     999.710000         2024-06-03 00:00:00  4.997675e+18  1.717402e+09
# std     288.791957                         NaN  1.215563e+18  4.951866e+08

# %%
# %%timeit -n 100
import numpy as np

print(np.round(np.sum(sales_df['total_price']), 3))
# Out:
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 1.21 ms ± 204 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
import numpy as np
total = 0
for price in sales_df['total_price']:
    total += price
print(np.round(total, 3))
# Out:
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 489713.8
# 2.09 ms ± 361 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## Queries and Transformations

# %%
# drop a column
sales_copy_df = sales_df.copy()
print(sales_copy_df.columns)
sales_copy_df = sales_copy_df.drop(columns=['timestamp'], axis=1)
sales_copy_df.head()
# Out:
# Index(['code', 'client', 'total_price', 'date', 'hour', 'credit_card',
#        'date_full', 'timestamp'],
#       dtype='object')
#              code           client  total_price       date      hour  \
# 0  Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# 1  Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# 2  Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# 3  Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# 4  Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#         credit_card             date_full
# 0  6011811575065598  2024-Jun-03 08:13:18
# 1  6536303182814044  2014-Aug-22 02:57:20
# 2   213185615148626  1979-May-22 02:10:06
# 3  3558512811558836  1973-Dec-24 21:28:34
# 4  2239583806605394  1974-Mar-14 03:55:36

# %%
# drop a row
sales_df = sales_df.set_index('code')
sales_copy_df = sales_df.copy()
sales_copy_df['country'] = 'Colombia'
print(sales_copy_df.head())
sales_copy_df = sales_copy_df.drop(index='Sale-8141-KGOb')
sales_copy_df.head()
# Out:
#                          client  total_price       date      hour  \
# code
# Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#                      credit_card             date_full   timestamp   country
# code
# Sale-1117-HdZH  6011811575065598  2024-Jun-03 08:13:18  1717402398  Colombia
# Sale-5078-hqkc  6536303182814044  2014-Aug-22 02:57:20  1408676240  Colombia
# Sale-8209-xGVn   213185615148626  1979-May-22 02:10:06   296187006  Colombia
# Sale-9093-bfcp  3558512811558836  1973-Dec-24 21:28:34   125616514  Colombia
# Sale-8141-KGOb  2239583806605394  1974-Mar-14 03:55:36   132465336  Colombia
#                          client  total_price       date      hour  \
# code
# Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# Sale-7567-cCLb    William Smith       857.13 2016-07-04  18:26:22
#
#                      credit_card             date_full   timestamp   country
# code
# Sale-1117-HdZH  6011811575065598  2024-Jun-03 08:13:18  1717402398  Colombia
# Sale-5078-hqkc  6536303182814044  2014-Aug-22 02:57:20  1408676240  Colombia
# Sale-8209-xGVn   213185615148626  1979-May-22 02:10:06   296187006  Colombia
# Sale-9093-bfcp  3558512811558836  1973-Dec-24 21:28:34   125616514  Colombia
# Sale-7567-cCLb  3541411469135312  2016-Jul-04 18:26:22  1467656782  Colombia

# %%
# query a dataframe by column
clients = sales_df['client']
print(type(clients))
print(clients.head())
# Out:
# <class 'pandas.core.series.Series'>
# code
# Sale-1117-HdZH          Gary Meza
# Sale-5078-hqkc       Carol Martin
# Sale-8209-xGVn     Jeremy Spencer
# Sale-9093-bfcp    Pamela Anderson
# Sale-8141-KGOb      Kenneth Marsh
# Name: client, dtype: object

# %%
# query a dataframe by row with loc
sales_df.loc['Sale-8209-xGVn', ['client', 'date']]
# Out:
# client         Jeremy Spencer
# date      1979-05-22 00:00:00
# Name: Sale-8209-xGVn, dtype: object

# %%
# query a dataframe by row with iloc
sales_df.iloc[2:5]
# Out:
#                          client  total_price       date      hour  \
# code
# Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#                      credit_card             date_full  timestamp
# code
# Sale-8209-xGVn   213185615148626  1979-May-22 02:10:06  296187006
# Sale-9093-bfcp  3558512811558836  1973-Dec-24 21:28:34  125616514
# Sale-8141-KGOb  2239583806605394  1974-Mar-14 03:55:36  132465336

# %%
# query a dataframe using a boolean mask
sales_df[sales_df['total_price'] > 600].head()
# Out:
#                         client  total_price       date      hour  \
# code
# Sale-1117-HdZH       Gary Meza       832.48 2024-06-03  08:13:18
# Sale-8209-xGVn  Jeremy Spencer       832.05 1979-05-22  02:10:06
# Sale-7567-cCLb   William Smith       857.13 2016-07-04  18:26:22
# Sale-1256-GSGV     Travis Reid       913.50 1987-01-01  12:19:45
# Sale-2412-paxo    James Harris       620.80 1970-09-29  09:31:03
#
#                         credit_card             date_full   timestamp
# code
# Sale-1117-HdZH     6011811575065598  2024-Jun-03 08:13:18  1717402398
# Sale-8209-xGVn      213185615148626  1979-May-22 02:10:06   296187006
# Sale-7567-cCLb     3541411469135312  2016-Jul-04 18:26:22  1467656782
# Sale-1256-GSGV       30435866051594  1987-Jan-01 12:19:45   536501985
# Sale-2412-paxo  4619378591392526336  1970-Sep-29 09:31:03    23448663

# %%
sales_df[(sales_df['total_price'] > 600) & (sales_df['date'] > '2016-01-01')].head()
# Out:
#                                client  total_price       date      hour  \
# code
# Sale-1117-HdZH              Gary Meza       832.48 2024-06-03  08:13:18
# Sale-7567-cCLb          William Smith       857.13 2016-07-04  18:26:22
# Sale-1938-dqto  Christopher Green DDS       994.77 2023-09-19  12:54:28
# Sale-5358-yFiM             Gene Davis       871.66 2023-06-18  18:04:39
# Sale-8546-Mwsg          William Payne       915.85 2019-09-25  02:57:57
#
#                      credit_card             date_full   timestamp
# code
# Sale-1117-HdZH  6011811575065598  2024-Jun-03 08:13:18  1717402398
# Sale-7567-cCLb  3541411469135312  2016-Jul-04 18:26:22  1467656782
# Sale-1938-dqto  4569498359626448  2023-Sep-19 12:54:28  1695128068
# Sale-5358-yFiM    36076121497968  2023-Jun-18 18:04:39  1687111479
# Sale-8546-Mwsg    30108709853944  2019-Sep-25 02:57:57  1569380277

# %%
# change all column names to Capital Case
sales_df.columns = sales_df.columns.str.capitalize()
sales_df.head()
# Out:
#                          Client  Total_price       Date      Hour  \
# code
# Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#                      Credit_card             Date_full   Timestamp
# code
# Sale-1117-HdZH  6011811575065598  2024-Jun-03 08:13:18  1717402398
# Sale-5078-hqkc  6536303182814044  2014-Aug-22 02:57:20  1408676240
# Sale-8209-xGVn   213185615148626  1979-May-22 02:10:06   296187006
# Sale-9093-bfcp  3558512811558836  1973-Dec-24 21:28:34   125616514
# Sale-8141-KGOb  2239583806605394  1974-Mar-14 03:55:36   132465336

# %%
print(sales_df.head())
sales_df = sales_df.reset_index()
sales_df.head()
# Out:
#                          Client  Total_price       Date      Hour  \
# code
# Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#                      Credit_card             Date_full   Timestamp
# code
# Sale-1117-HdZH  6011811575065598  2024-Jun-03 08:13:18  1717402398
# Sale-5078-hqkc  6536303182814044  2014-Aug-22 02:57:20  1408676240
# Sale-8209-xGVn   213185615148626  1979-May-22 02:10:06   296187006
# Sale-9093-bfcp  3558512811558836  1973-Dec-24 21:28:34   125616514
# Sale-8141-KGOb  2239583806605394  1974-Mar-14 03:55:36   132465336
#              code           Client  Total_price       Date      Hour  \
# 0  Sale-1117-HdZH        Gary Meza       832.48 2024-06-03  08:13:18
# 1  Sale-5078-hqkc     Carol Martin       156.29 2014-08-22  02:57:20
# 2  Sale-8209-xGVn   Jeremy Spencer       832.05 1979-05-22  02:10:06
# 3  Sale-9093-bfcp  Pamela Anderson       166.57 1973-12-24  21:28:34
# 4  Sale-8141-KGOb    Kenneth Marsh       498.43 1974-03-14  03:55:36
#
#         Credit_card             Date_full   Timestamp
# 0  6011811575065598  2024-Jun-03 08:13:18  1717402398
# 1  6536303182814044  2014-Aug-22 02:57:20  1408676240
# 2   213185615148626  1979-May-22 02:10:06   296187006
# 3  3558512811558836  1973-Dec-24 21:28:34   125616514
# 4  2239583806605394  1974-Mar-14 03:55:36   132465336

# %%
# get availables values in a column
print(sales_df['Date'].size)
print(sales_df['Date'].unique())
# Out:
# 1000
# <DatetimeArray>
# ['2024-06-03 00:00:00', '2014-08-22 00:00:00', '1979-05-22 00:00:00',
#  '1973-12-24 00:00:00', '1974-03-14 00:00:00', '2016-07-04 00:00:00',
#  '2010-07-18 00:00:00', '1988-11-18 00:00:00', '1987-01-01 00:00:00',
#  '2017-11-06 00:00:00',
#  ...
#  '2012-10-15 00:00:00', '1994-02-06 00:00:00', '2003-08-16 00:00:00',
#  '2018-09-26 00:00:00', '2007-12-19 00:00:00', '2002-10-24 00:00:00',
#  '1999-06-29 00:00:00', '1991-11-27 00:00:00', '1979-07-07 00:00:00',
#  '1972-03-07 00:00:00']
# Length: 981, dtype: datetime64[ns]

# %%
# query a dataframe using query()
sales_df.query('Total_price > 600').head()
# Out:
#               code          Client  Total_price       Date      Hour  \
# 0   Sale-1117-HdZH       Gary Meza       832.48 2024-06-03  08:13:18
# 2   Sale-8209-xGVn  Jeremy Spencer       832.05 1979-05-22  02:10:06
# 5   Sale-7567-cCLb   William Smith       857.13 2016-07-04  18:26:22
# 8   Sale-1256-GSGV     Travis Reid       913.50 1987-01-01  12:19:45
# 12  Sale-2412-paxo    James Harris       620.80 1970-09-29  09:31:03
#
#             Credit_card             Date_full   Timestamp
# 0      6011811575065598  2024-Jun-03 08:13:18  1717402398
# 2       213185615148626  1979-May-22 02:10:06   296187006
# 5      3541411469135312  2016-Jul-04 18:26:22  1467656782
# 8        30435866051594  1987-Jan-01 12:19:45   536501985
# 12  4619378591392526336  1970-Sep-29 09:31:03    23448663

# %%
sales_df.query('Total_price > 600 and Date > "2016-01-01"').head()
# Out:
#               code                 Client  Total_price       Date      Hour  \
# 0   Sale-1117-HdZH              Gary Meza       832.48 2024-06-03  08:13:18
# 5   Sale-7567-cCLb          William Smith       857.13 2016-07-04  18:26:22
# 18  Sale-1938-dqto  Christopher Green DDS       994.77 2023-09-19  12:54:28
# 59  Sale-5358-yFiM             Gene Davis       871.66 2023-06-18  18:04:39
# 81  Sale-8546-Mwsg          William Payne       915.85 2019-09-25  02:57:57
#
#          Credit_card             Date_full   Timestamp
# 0   6011811575065598  2024-Jun-03 08:13:18  1717402398
# 5   3541411469135312  2016-Jul-04 18:26:22  1467656782
# 18  4569498359626448  2023-Sep-19 12:54:28  1695128068
# 59    36076121497968  2023-Jun-18 18:04:39  1687111479
# 81    30108709853944  2019-Sep-25 02:57:57  1569380277

# %%
# get missing values using isnull()
call_center_df = pd.read_json('json-files/call_center_comments.json')
print(call_center_df.info())
print("*"*50)
print(call_center_df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   code               1000000 non-null  object
#  1   client             1000000 non-null  object
#  2   product            1000000 non-null  object
#  3   date_time          979847 non-null   datetime64[ns]
#  4   attention_time     950263 non-null   float64
#  5   comment            1000000 non-null  object
#  6   country_of_origin  1000000 non-null  object
#  7   city               858525 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 61.0+ MB
# None
# **************************************************
# code                      0
# client                    0
# product                   0
# date_time             20153
# attention_time        49737
# comment                   0
# country_of_origin         0
# city                 141475
# dtype: int64

# %%
# fill missing values using fillna()
# fill missing attention_time with average time
import numpy as np
call_center_filled_df = call_center_df.copy()
call_center_filled_df['attention_time'] = call_center_filled_df['attention_time'].fillna(np.mean(call_center_df['attention_time']))
print(call_center_filled_df.isnull().sum())

# fill missing city with not reported
call_center_filled_df['city'] = call_center_filled_df['city'].fillna('Not reported')
print(call_center_filled_df.isnull().sum())

# fill missing values using fillna() in date_time column with interopolation
call_center_filled_df['date_time'] = call_center_filled_df['date_time'].interpolate()
print(call_center_filled_df.isnull().sum())
print(call_center_filled_df.info())
call_center_filled_df.head()
# Out:
# code                      0
# client                    0
# product                   0
# date_time             20153
# attention_time            0
# comment                   0
# country_of_origin         0
# city                 141475
# dtype: int64
# code                     0
# client                   0
# product                  0
# date_time            20153
# attention_time           0
# comment                  0
# country_of_origin        0
# city                     0
# dtype: int64
# code                 0
# client               0
# product              0
# date_time            0
# attention_time       0
# comment              0
# country_of_origin    0
# city                 0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   code               1000000 non-null  object
#  1   client             1000000 non-null  object
#  2   product            1000000 non-null  object
#  3   date_time          1000000 non-null  datetime64[ns]
#  4   attention_time     1000000 non-null  float64
#  5   comment            1000000 non-null  object
#  6   country_of_origin  1000000 non-null  object
#  7   city               1000000 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 61.0+ MB
# None
#           code           client               product           date_time  \
# 0  eer-4490986   Laurie Wallace                   SSD 2020-02-29 17:51:25
# 1  qDL-3585949     Craig Harris         Graphics Card 2023-10-26 10:12:43
# 2  sQo-4191674      Cody Romero            VR Headset 2022-08-07 02:52:48
# 3  QAy-6767272    Renee Sanchez         Graphics Card 2020-03-21 19:23:23
# 4  lAI-7220154  Anthony Collins  Smart Home Assistant 2021-01-08 14:00:46
#
#    attention_time                                          comment  \
# 0       86.740331  Significantly improved my computer's boot time.
# 1       77.534184                  Runs cool and quiet under load.
# 2      104.754283           Immersive gaming and media experience.
# 3       86.052689        Pricey, but worth it for the performance.
# 4       35.819705        Concerns about privacy and data security.
#
#   country_of_origin            city
# 0            Brazil  Belo Horizonte
# 1               USA    Not reported
# 2            Russia           Kazan
# 3             India         Kolkata
# 4             Italy            Rome

# %%
# drop missing values using dropna()
cleaned_df = call_center_df.dropna()
print(cleaned_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 799390 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   code               799390 non-null  object
#  1   client             799390 non-null  object
#  2   product            799390 non-null  object
#  3   date_time          799390 non-null  datetime64[ns]
#  4   attention_time     799390 non-null  float64
#  5   comment            799390 non-null  object
#  6   country_of_origin  799390 non-null  object
#  7   city               799390 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 54.9+ MB
# None

# %%
# transform column using to_datetime()
call_center_df['dt_str'] = call_center_df['date_time'].astype(str)
print(call_center_df.info())
call_center_df['dt'] = pd.to_datetime(call_center_df['dt_str'])
print(call_center_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   code               1000000 non-null  object
#  1   client             1000000 non-null  object
#  2   product            1000000 non-null  object
#  3   date_time          979847 non-null   datetime64[ns]
#  4   attention_time     950263 non-null   float64
#  5   comment            1000000 non-null  object
#  6   country_of_origin  1000000 non-null  object
#  7   city               858525 non-null   object
#  8   dt_str             1000000 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 68.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   code               1000000 non-null  object
#  1   client             1000000 non-null  object
#  2   product            1000000 non-null  object
#  3   date_time          979847 non-null   datetime64[ns]
#  4   attention_time     950263 non-null   float64
#  5   comment            1000000 non-null  object
#  6   country_of_origin  1000000 non-null  object
#  7   city               858525 non-null   object
#  8   dt_str             1000000 non-null  object
#  9   dt                 979847 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(7)
# memory usage: 76.3+ MB
# None

# %%
# transform column using to_numeric()
call_center_df['at_str'] = call_center_df['attention_time'].astype(str)
print(call_center_df.info())
call_center_df['at'] = pd.to_numeric(call_center_df['at_str'], errors='coerce')
print(call_center_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   code               1000000 non-null  object
#  1   client             1000000 non-null  object
#  2   product            1000000 non-null  object
#  3   date_time          979847 non-null   datetime64[ns]
#  4   attention_time     950263 non-null   float64
#  5   comment            1000000 non-null  object
#  6   country_of_origin  1000000 non-null  object
#  7   city               858525 non-null   object
#  8   dt_str             1000000 non-null  object
#  9   dt                 979847 non-null   datetime64[ns]
#  10  at_str             1000000 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(8)
# memory usage: 83.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   code               1000000 non-null  object
#  1   client             1000000 non-null  object
#  2   product            1000000 non-null  object
#  3   date_time          979847 non-null   datetime64[ns]
#  4   attention_time     950263 non-null   float64
#  5   comment            1000000 non-null  object
#  6   country_of_origin  1000000 non-null  object
#  7   city               858525 non-null   object
#  8   dt_str             1000000 non-null  object
#  9   dt                 979847 non-null   datetime64[ns]
#  10  at_str             1000000 non-null  object
#  11  at                 950263 non-null   float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 91.6+ MB
# None

# %%
# convert column to category using astype()
call_center_df = call_center_df.drop(columns=['dt_str', 'at_str'])
del call_center_df['dt']
del call_center_df['at']
call_center_df = call_center_df.rename(columns={'country_of_origin': 'country'})
call_center_df['country'] = call_center_df['country'].astype('category')
call_center_df['city'] = call_center_df['city'].astype('category')
print(call_center_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   code            1000000 non-null  object
#  1   client          1000000 non-null  object
#  2   product         1000000 non-null  object
#  3   date_time       979847 non-null   datetime64[ns]
#  4   attention_time  950263 non-null   float64
#  5   comment         1000000 non-null  object
#  6   country         1000000 non-null  category
#  7   city            858525 non-null   category
# dtypes: category(2), datetime64[ns](1), float64(1), object(4)
# memory usage: 47.7+ MB
# None

# %% [markdown]
# ### Students Info for Merge and Joining

# %%
df_csv.columns = df_csv.columns.str.lower()
df_csv.head()
# Out:
#             name                         company                     position  \
# 0  Alice Johnson  Hernandez, Griffith and Nelson           Petroleum engineer
# 1    David Jones                    Gomez-Garcia       Geologist, engineering
# 2      Eva Brown                     Blevins LLC               Microbiologist
# 3    Frank Davis                   Greene-Wilson     Museum education officer
# 4  Jack Anderson                      Butler PLC  Scientist, research (maths)
#
#    salary
# 0    4740
# 1   73329
# 2   83245
# 3   74390
# 4   69851

# %%
df_json.head()
# Out:
#    id            name                  career                college
# 0   1   Alice Johnson        Computer Science        Tech University
# 1   2       Bob Smith  Mechanical Engineering  Engineering Institute
# 2   3  Carol Williams  Electrical Engineering        Tech University
# 3   4     David Jones                 Biology        Science College
# 4   5       Eva Brown                 Physics        Tech University

# %%
# merge dataframes using merge()
students_merge_df = pd.merge(df_csv, df_json, on='name')
students_merge_df.to_csv('csv-files/students_merge.csv', index=False)
students_merge_df.head()
# Out:
#             name                         company                     position  \
# 0  Alice Johnson  Hernandez, Griffith and Nelson           Petroleum engineer
# 1    David Jones                    Gomez-Garcia       Geologist, engineering
# 2      Eva Brown                     Blevins LLC               Microbiologist
# 3    Frank Davis                   Greene-Wilson     Museum education officer
# 4  Jack Anderson                      Butler PLC  Scientist, research (maths)
#
#    salary  id                career          college
# 0    4740   1      Computer Science  Tech University
# 1   73329   4               Biology  Science College
# 2   83245   5               Physics  Tech University
# 3   74390   6             Chemistry  Science College
# 4   69851  10  Software Engineering  Tech University

# %%
# concatenate dataframes using concat()
students_concat_df = pd.concat([df_csv, df_json], axis=0)
students_concat_df.to_csv('csv-files/students_concat.csv', index=False)
students_concat_df.head()
# Out:
#             name                         company                     position  \
# 0  Alice Johnson  Hernandez, Griffith and Nelson           Petroleum engineer
# 1    David Jones                    Gomez-Garcia       Geologist, engineering
# 2      Eva Brown                     Blevins LLC               Microbiologist
# 3    Frank Davis                   Greene-Wilson     Museum education officer
# 4  Jack Anderson                      Butler PLC  Scientist, research (maths)
#
#     salary  id career college
# 0   4740.0 NaN    NaN     NaN
# 1  73329.0 NaN    NaN     NaN
# 2  83245.0 NaN    NaN     NaN
# 3  74390.0 NaN    NaN     NaN
# 4  69851.0 NaN    NaN     NaN

# %%
temp_concat_df = pd.concat([df_csv, df_csv.copy()], axis=0).reset_index(drop=True)
print(temp_concat_df.info())
print("*"*50)
temp_concat_df = temp_concat_df.drop_duplicates()
print(temp_concat_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      60 non-null     object
#  1   company   60 non-null     object
#  2   position  60 non-null     object
#  3   salary    60 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.0+ KB
# None
# **************************************************
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      30 non-null     object
#  1   company   30 non-null     object
#  2   position  30 non-null     object
#  3   salary    30 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.2+ KB
# None

# %%
df_csv = df_csv.set_index('name')
df_json = df_json.set_index('name')

# %%
# join dataframes using join()
students_join_df = df_csv.join(df_json, how='inner')
students_join_df.to_csv('csv-files/students_join.csv')
students_join_df.head()
# Out:
#                                       company                     position  \
# name
# Alice Johnson  Hernandez, Griffith and Nelson           Petroleum engineer
# David Jones                      Gomez-Garcia       Geologist, engineering
# Eva Brown                         Blevins LLC               Microbiologist
# Frank Davis                     Greene-Wilson     Museum education officer
# Jack Anderson                      Butler PLC  Scientist, research (maths)
#
#                salary  id                career          college
# name
# Alice Johnson    4740   1      Computer Science  Tech University
# David Jones     73329   4               Biology  Science College
# Eva Brown       83245   5               Physics  Tech University
# Frank Davis     74390   6             Chemistry  Science College
# Jack Anderson   69851  10  Software Engineering  Tech University

# %% [markdown]
# ### Coming Back to the CallCenter

# %%
# group dataframes using groupby()
# groupby by country
for country, country_df in call_center_df.groupby('country'):
    print(country)
    print(country_df.head())
# Out:
# /tmp/ipykernel_350011/643197461.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for country, country_df in call_center_df.groupby('country'):
# Australia
#            code           client           product           date_time  \
# 7   iQI-5637711  Richard Herrera  Wireless Charger                 NaT
# 34  duD-2082213    Jamie Estrada   Streaming Stick 2022-01-29 18:05:49
# 40  aLz-4866545     James Nelson    Digital Camera 2024-05-20 03:33:30
# 58  aNx-4547164    Michael Davis           Monitor 2021-12-09 20:56:03
# 69  wiz-4312029  Jennifer Murray        3D Printer 2024-05-29 17:10:56
#
#     attention_time                               comment    country      city
# 7        90.696875  Charging speed is slower than wired.  Australia    Sydney
# 34       46.029668         Turns any TV into a smart TV.  Australia  Canberra
# 40      146.931571   Compact and easy to carry on trips.  Australia  Canberra
# 58       77.915983       Stand could be more adjustable.  Australia  Adelaide
# 69       11.571618            Material costs can add up.  Australia     Perth
# Brazil
#            code               client              product           date_time  \
# 0   eer-4490986       Laurie Wallace                  SSD 2020-02-29 17:51:25
# 9   RSM-6852615             Joe Hill  External Hard Drive 2022-10-07 10:06:19
# 19  viG-3123990      Michelle Taylor      USB Flash Drive 2021-06-06 23:20:09
# 53  WnE-3297972  Stephanie Little MD     Wireless Charger 2022-09-19 17:16:53
# 54  NgI-3255420       Craig Roberson               Tablet 2022-06-23 23:40:49
#
#     attention_time                                          comment country  \
# 0        86.740331  Significantly improved my computer's boot time.  Brazil
# 9       140.827411           Transfer speeds are fast and reliable.  Brazil
# 19      146.901178                    Write speeds could be faster.  Brazil
# 53      104.851385   Needs precise placement to charge effectively.  Brazil
# 54       26.194469                  Light and easy to carry around.  Brazil
#
#               city
# 0   Belo Horizonte
# 9   Belo Horizonte
# 19  Rio de Janeiro
# 53       São Paulo
# 54             NaN
# Canada
#             code          client                      product  \
# 6    SxB-4119613  Timothy Rogers              USB Flash Drive
# 70   Hmp-9656645  Miguel Stanley             Wireless Charger
# 90   AIn-2613323   Brittany Gray               Gaming Console
# 112  ZJU-6074483   Ryan Gonzalez               Gaming Console
# 123  SDU-0600770  Jason Morrison  Noise Cancelling Headphones
#
#               date_time  attention_time  \
# 6   2024-01-10 13:23:40       77.976127
# 70  2021-06-08 23:38:45       94.280573
# 90  2020-07-17 07:03:20       29.485895
# 112 2022-12-01 19:19:09       25.348683
# 123 2020-02-16 17:04:12             NaN
#
#                                                comment country       city
# 6                Small and portable, but easy to lose.  Canada  Vancouver
# 70                   Convenient, just drop and charge.  Canada    Calgary
# 17      137.588234        Reliable and fast storage solution.      UK
# 42      148.889133         Great for gaming with low latency.      UK
# 44       97.716205  Pricey, but worth it for the performance.      UK
# 46       19.747415     Transfer speeds are fast and reliable.      UK
# 66       82.228689          Perfect for both work and gaming.      UK
#
#           city
# 17  Birmingham
# 42  Birmingham
# 44     Glasgow
# 46   Liverpool
# 66         NaN
# USA
#             code         client            product           date_time  \
# 1    qDL-3585949   Craig Harris      Graphics Card 2023-10-26 10:12:43
# 47   XTs-5926647      Erin Love  Bluetooth Speaker 2021-12-22 03:19:58
# 68   HvK-7192312   Pamela Casey      Graphics Card                 NaT
# 79   BAt-7155448     Joseph Liu     Gaming Console 2023-07-03 20:56:02
# 103  Coo-9901233  Kelly Collins         VR Headset 2020-07-23 09:44:53
#
#      attention_time                                    comment country  \
# 1               NaN            Runs cool and quiet under load.     USA
# 47        64.554752          Great sound quality for its size.     USA
# 68       106.058759  Pricey, but worth it for the performance.     USA
# 79       149.450178   Controller battery life could be better.     USA
# 103      120.150219     Immersive gaming and media experience.     USA
#
#               city
# 1              NaN
# 47         Chicago
# 68         Seattle
# 79             NaN
# 103  San Francisco

# %%
# groupby by country and city
for (country, city), country_city_df in call_center_df.groupby(['country', 'city']):
    print(country, city)
    print(country_city_df.head())
# Out:
# /tmp/ipykernel_350011/3881247478.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for (country, city), country_city_df in call_center_df.groupby(['country', 'city']):
# Australia Adelaide
#             code          client            product           date_time  \
# 58   aNx-4547164   Michael Davis            Monitor 2021-12-09 20:56:03
# 82   AxV-5493389      Amy Dillon      Graphics Card 2024-02-09 10:56:23
# 251  guI-8126215      Corey Gray             Tablet 2023-11-02 11:39:20
# 285  EzZ-7506837  Dylan Price MD   Wireless Charger 2021-12-28 09:58:18
# 481  TuI-4167846  Brittany Hardy  Bluetooth Speaker 2023-04-02 11:27:15
#
#      attention_time                                    comment    country  \
# 58        77.915983            Stand could be more adjustable.  Australia
# 82       137.804867  Pricey, but worth it for the performance.  Australia
# 251      136.081584            Light and easy to carry around.  Australia
# 285       57.067966       Charging speed is slower than wired.  Australia
# 481       28.677439          Great sound quality for its size.  Australia
#
#          city
# 58   Adelaide
# 82   Adelaide
# 251  Adelaide
# 285  Adelaide
# 481  Adelaide
# Australia Brisbane
#             code             client           product           date_time  \
# 384  Iga-7109437          Lisa Cruz  Desktop Computer 2024-03-05 14:00:14
# 532  kIP-5039364        Scott Davis    Gaming Console 2020-11-08 18:55:15
# 546  WTe-6555437     Kimberly Ellis        3D Printer 2022-04-14 05:07:13
# 716  RCN-6258853       Amber Ortega        VR Headset 2020-03-28 12:02:23
# 800  Azb-8967733  Pamela Fuller PhD     Graphics Card 2024-06-23 06:29:37
#
#      attention_time                                           comment  \
# 384      132.264598  Powerful performance for all my computing needs.
# 532       53.864352          Controller battery life could be better.
# 546      137.958391      Setup and calibration can be time-consuming.
# 716       70.630642  Requires a lot of space for the best experience.
# 800       35.519413         Pricey, but worth it for the performance.
#
#        country      city
# 384  Australia  Brisbane
#
#      attention_time                                       comment country  \
# 70        94.280573             Convenient, just drop and charge.  Canada
# 166       30.923837                  Motivates me to stay active.  Canada
# 208      146.431650               Light and easy to carry around.  Canada
# 259       53.428874  Sometimes lags with high-resolution content.  Canada
# 371       53.477446     Pricey, but worth it for the performance.  Canada
#
#         city
# 70   Calgary
# 166  Calgary
# 208  Calgary
# 259  Calgary
# 371  Calgary
# Canada Edmonton
#             code               client             product           date_time  \
# 155  kiQ-7054021       Laura Martinez     Streaming Stick 2020-01-13 13:54:18
# 170  XVI-3470475        Kristina Wall  Portable Projector 2021-11-22 06:35:16
# 364  lLj-0142992     Stephanie Thomas          Smart Lock 2023-05-31 13:52:38
# 401  cud-6081904  Stephen Estrada Jr.     USB Flash Drive 2020-10-25 20:29:34
# 524  ouK-7057125         Kelly Haynes                 SSD 2024-03-16 08:41:12
#
#      attention_time                                       comment country  \
# 155       95.603315  Sometimes lags with high-resolution content.  Canada
# 170      137.446215                 Battery life could be longer.  Canada
# 364      101.702337     Adds convenience and security to my home.  Canada
# 401       63.025754                 Write speeds could be faster.  Canada
# 524       88.516618                   Capacity can get expensive.  Canada
#
#          city
# 155  Edmonton
# 170  Edmonton
# 364  Edmonton
# 401  Edmonton
# 524  Edmonton
# Canada Montreal
#             code              client                      product  \
# 112  ZJU-6074483       Ryan Gonzalez               Gaming Console
# 123  SDU-0600770      Jason Morrison  Noise Cancelling Headphones
# 289  xDl-0287498       Brenda Duncan              Fitness Tracker
# 344  sQV-1630171  Dr. Jennifer Ayala                   Smart Lock
# 363  kBx-3963140     James Carpenter             Desktop Computer
#
#               date_time  attention_time  \
# 112 2022-12-01 19:19:09       25.348683
# 123 2020-02-16 17:04:12             NaN
# 289                 NaT      111.915146
# 344 2020-01-19 10:13:18       19.944018
# 363 2023-09-04 08:09:36      113.586773
#
#                                                comment country      city
# 112          Excellent game selection and performance.  Canada  Montreal
# 123  Can be uncomfortable during long listening ses...  Canada  Montreal
# 289       Accuracy can vary depending on the activity.  Canada  Montreal
# 344          Adds convenience and security to my home.  Canada  Montreal
# 363                     Easy to upgrade and customize.  Canada  Montreal
# Canada Ottawa
#             code         client               product           date_time  \
# 90   AIn-2613323  Brittany Gray        Gaming Console 2020-07-17 07:03:20
# 217  fFG-3282704  Lauren Castro  Smart Home Assistant 2021-11-13 18:20:36
# 218  uBC-3592928   David Miller    Portable Projector 2020-01-13 07:38:05
# 245  apT-9942524  William Brown      Wireless Charger 2021-05-19 20:40:57
# 273  EXe-6395792   Wayne Howard            3D Printer                 NaT
#
#      attention_time                                         comment country  \
# 90        29.485895  Quiet operation, even during intense gameplay.  Canada
# 217      138.378188      Makes controlling smart home devices easy.  Canada
# 218       10.732640     Brightness is adequate for dimly lit rooms.  Canada
# 245      129.302650               Convenient, just drop and charge.  Canada
# 273       86.139996    Setup and calibration can be time-consuming.  Canada
#
#        city
# 90   Ottawa
# 217  Ottawa
# 218  Ottawa
# 245  Ottawa
# 273  Ottawa
#
#      attention_time                                           comment country  \
# 163      121.665636           Great for reading and streaming videos.   China
# 202      101.400592                 Great sound quality for its size.   China
# 314      101.107487             Excellent image quality and features.   China
# 571      123.046846  Powerful performance for all my computing needs.   China
# 669        7.438983          Battery lasts all day with moderate use.   China
#
#         city
# 163  Chengdu
# 202  Chengdu
# 314  Chengdu
# 571  Chengdu
# 669  Chengdu
# China Guangzhou
#             code            client           product           date_time  \
# 37   eyy-3739283      Larry Jordan     Action Camera 2021-01-07 04:00:08
# 136  ZuT-0322701        John Glass        Smartphone 2023-05-28 23:54:28
# 203  OOE-9501674   Hannah Figueroa        Smart Lock 2023-05-04 21:51:53
# 286  GlB-0842359  Mr. John Stanley  Smart Thermostat 2020-03-31 01:52:49
# 680  ccx-0839964    Jennifer Moore     Graphics Card 2023-03-06 05:40:35
#
#      attention_time                                      comment country  \
# 37        35.173205  Battery drains quickly with continuous use.   China
# 136       88.884043            Wish it had more storage options.   China
# 203       38.439434    Setup was more complicated than expected.   China
# 286       66.727968               Installation was a bit tricky.   China
# 680      114.644438    Pricey, but worth it for the performance.   China
#
#           city
# 37   Guangzhou
# 136  Guangzhou
# 203  Guangzhou
# 286  Guangzhou
# 680  Guangzhou
# China Shanghai
#             code            client              product           date_time  \
# 109  Ijk-4270628     Wayne Morales             E-Reader 2021-07-21 15:42:43
# 247  HKJ-3912611      Robert Lyons  External Hard Drive 2020-12-23 19:04:22
# 369  NJH-5142146  Andrew Rodriguez     Wireless Charger 2021-07-17 10:26:47
# 544  WjE-2483757       Larry Munoz      Fitness Tracker 2020-04-28 08:05:39
# 557  FPv-6704385      Connie Smith     Wireless Charger 2020-09-15 11:01:53
#
#      attention_time                                       comment country  \
# 109       16.254108  Makes reading at night comfortable and easy.   China
# 247      104.602667                          Feels a bit fragile.   China
# 369       94.165980             Convenient, just drop and charge.   China
# 544      136.450643                  Motivates me to stay active.   China
# 557       12.538956          Charging speed is slower than wired.   China
#
#          city
# 109  Shanghai
# 247  Shanghai
# 369  Shanghai
# 544  Shanghai
# 557  Shanghai
# China Shenzhen
#             code              client                      product  \
# 77   AJi-5560180        Cheryl Davis              Fitness Tracker
# 118  bDg-6491927           Amy Smith                   3D Printer
# 179  wgS-0233833     Carmen Anderson                      Monitor
# 181  rQD-3296783   Michael Carpenter  Noise Cancelling Headphones
# 186  LNh-4079242  Samantha Fernandez  Noise Cancelling Headphones
#
#               date_time  attention_time  \
# 77  2021-01-07 23:54:29       95.111462
# 118 2022-09-11 18:19:52       27.400343
# 179 2024-04-22 00:32:43       94.386927
# 181 2021-04-01 21:28:22      144.407576
# 186 2021-10-09 09:07:22      143.287196
#
#                                           comment country      city
# 77                   Motivates me to stay active.   China  Shenzhen
# 118     Great for prototyping and hobby projects.   China  Shenzhen
# 179  Colors are vibrant and the display is sharp.   China  Shenzhen
# 181                   Sound quality is top-notch.   China  Shenzhen
# 186                   Sound quality is top-notch.   China  Shenzhen
# China Xi'an
#             code            client           product           date_time  \
# 429 2022-03-13 20:08:27       18.142342
#
#                                              comment  country    city
# 36   Wide-angle lens captures stunning perspectives.  Germany  Berlin
# 149                Wish it had more storage options.  Germany  Berlin
# 216                Perfect for both work and gaming.  Germany  Berlin
# 224                       Compact and easy to carry.  Germany  Berlin
# 429           Immersive gaming and media experience.  Germany  Berlin
# Germany Cologne
#             code             client             product           date_time  \
# 96   fYO-1934969       Katie Martin          3D Printer 2023-01-16 17:35:04
# 111  HEz-2322539     Patrick Harmon          Smart Lock 2023-02-06 09:13:46
# 220  Fna-9120178  Stephanie Holland    Smart Thermostat 2020-03-25 22:04:10
# 258  lBm-2206074       Charles Hall     Wireless Router 2021-12-08 15:42:05
# 394  tQE-8217332    Veronica Miller  Portable Projector 2020-12-20 19:59:40
#
#      attention_time                                            comment  \
# 96        62.838199       Setup and calibration can be time-consuming.
# 111       18.374390          Adds convenience and security to my home.
# 220       48.979129                     Easy to control from my phone.
# 258       70.675899  Strong and stable Wi-Fi coverage throughout my...
# 394       44.050043        Brightness is adequate for dimly lit rooms.
#
#      country     city
# 96   Germany  Cologne
# 111  Germany  Cologne
# 220  Germany  Cologne
# 258  Germany  Cologne
# 394  Germany  Cologne
# Germany Frankfurt
#             code            client              product           date_time  \
# 18   dbz-4944874      Lisa Stewart  External Hard Drive 2024-03-09 11:54:48
# 22   gxo-8337812     Brandi Arnold     Smart Thermostat 2022-11-15 10:41:00
# 63   Vel-0158414  Jeffrey Griffith               Tablet 2023-07-24 07:15:03
# 337  xRw-7233363    Deborah Taylor     Wireless Charger 2020-03-20 10:51:37
# 441  NOC-0304345     Brenda Sexton     Desktop Computer 2021-07-12 06:43:15
#
#      attention_time                                  comment  country  \
# 18              NaN                     Feels a bit fragile.  Germany
# 22       130.526197      Saves on heating and cooling costs.  Germany
# 63        40.783033  Great for reading and streaming videos.  Germany
# 337       51.368515     Charging speed is slower than wired.  Germany
# 441      121.805078                 Takes up a lot of space.  Germany
#
#           city
# 18   Frankfurt
# 22   Frankfurt
# 63   Frankfurt
# 337  Frankfurt
# 441  Frankfurt
# Germany Hamburg
#             code            client          product           date_time  \
# 195  ksH-9104678     Anthony Mills       3D Printer 2022-05-02 18:04:41
# 486  LYP-0061178        Dana Jones  Wireless Router 2023-08-20 14:09:25
# 610  XRo-7629758         Ryan Buck  Streaming Stick 2022-05-14 15:17:18
# 693  uuu-1867563  Derrick Buchanan            Drone 2024-01-13 02:51:24
# 700  VeA-5379391    Kelly Williams       VR Headset 2022-06-16 14:19:08
#
#      attention_time                                           comment  \
# 195      133.043733      Setup and calibration can be time-consuming.
# 486      122.195452                               Setup was a breeze.
# 610       10.988167      Sometimes lags with high-resolution content.
# 693       53.980881           Takes amazing aerial photos and videos.
# 700       63.223973  Requires a lot of space for the best experience.
#
#      country     city
# 195  Germany  Hamburg
# 486  Germany  Hamburg
# 610  Germany  Hamburg
# 693  Germany  Hamburg
# 700  Germany  Hamburg
# Germany Munich
#             code            client             product           date_time  \
# 348  bmW-8776752       Isaac Smith  Portable Projector 2022-04-20 23:02:31
# 612  uba-5103473    Danielle Bruce       Action Camera 2020-04-27 09:53:30
#
#      attention_time                                      comment country  \
# 49        49.237195                      Easy to set up and use.   India
# 227      134.855486                  Capacity can get expensive.   India
# 240       21.969087                      Easy to set up and use.   India
# 348      130.798568                Battery life could be longer.   India
# 612      112.928696  Battery drains quickly with continuous use.   India
#
#        city
# 49   Mumbai
# 227  Mumbai
# 240  Mumbai
# 348  Mumbai
# 612  Mumbai
# Italy Genoa
#             code             client                      product  \
# 101  nQZ-0807041         Candace Li             Desktop Computer
# 102  VaV-5391668     Jeanette Adams                       Tablet
# 230  ktO-2083134         Ruth Moore                       Laptop
# 339  wZO-1773150  Douglas Fernandez                          SSD
# 390  PBm-6232546   Vincent Martinez  Noise Cancelling Headphones
#
#               date_time  attention_time  \
# 101 2023-12-26 05:46:31      114.436587
# 102 2024-02-29 09:34:43       35.437793
# 230 2022-01-23 00:12:19        9.952069
# 339 2020-11-11 00:15:24       37.805996
# 390 2023-12-17 14:31:17       27.000420
#
#                                              comment country   city
# 101                   Easy to upgrade and customize.   Italy  Genoa
# 102                      Could use more accessories.   Italy  Genoa
# 230         Incredible battery life and performance.   Italy  Genoa
# 339  Significantly improved my computer's boot time.   Italy  Genoa
# 390                      Sound quality is top-notch.   Italy  Genoa
# Italy Milan
#             code             client           product           date_time  \
# 10   pwG-1573678         Brian Cruz  Wireless Charger 2021-03-22 04:30:15
# 31   eec-5709882  Mrs. Ashley Jones   USB Flash Drive 2024-05-08 03:08:43
# 158  WOr-7288283    Michael Schultz  Desktop Computer 2021-04-26 20:36:15
# 272  LtA-6907647          Amy Glass        Smartphone 2022-09-27 07:15:13
# 275  RyG-3742752        Joel Butler    Gaming Console 2023-01-11 01:20:22
#
#      attention_time                                           comment country  \
# 10        55.251713                 Convenient, just drop and charge.   Italy
# 31       139.998344             Small and portable, but easy to lose.   Italy
# 158       61.352280  Powerful performance for all my computing needs.   Italy
# 272      138.774492  Amazing camera quality, especially in low light.   Italy
# 275       14.088250    Quiet operation, even during intense gameplay.   Italy
#
#       city
# 10   Milan
# 31   Milan
# 158  Milan
# 272  Milan
# 275  Milan
# Italy Naples
#             code           client           product           date_time  \
# 25   nws-0989540      Kelli Lyons       Smart Watch 2021-06-19 09:11:39
# 45   kxB-1896962    Sandra Norman           Monitor 2023-09-17 23:36:08
# 194  DNW-6263143  Andrea Williams  Desktop Computer 2024-06-09 04:54:27
# 356  QyW-5570592  Michael Burnett             Drone 2021-09-11 01:03:40
# 360  IzK-6930253       Sara Adams     Action Camera 2020-03-10 09:10:03
#
#      attention_time                                            comment  \
# 25        17.482463               Battery life is good, but not great.
# 45       109.471950       Colors are vibrant and the display is sharp.
# 194      148.780815                           Takes up a lot of space.
# 356      121.544570                      Learning curve for beginners.
# 360       69.660341  Durable and waterproof, great for adventure sp...
#
#     country    city
# 25    Italy  Naples
# 45    Italy  Naples
# 194   Italy  Naples
# 356   Italy  Naples
# 360   Italy  Naples
# Italy Palermo
#             code                  client            product  \
# 16   fAy-1566403           Eddie Hopkins  Bluetooth Speaker
# 20   cqm-2135694              Lisa Lopez            Monitor
# 30   REO-9009427  Dr. Andrea Johnson DVM         3D Printer
# 52   rSl-8600943            Sue Mcdonald      Graphics Card
# 100  WLh-9368098          Glen Hernandez              Drone
#
# ...
# 813       42.177422  Quiet operation, even during intense gameplay.   Spain
#
#         city
# 288  Seville
# 366  Seville
# 727  Seville
# 793  Seville
# 813  Seville
# Spain Valencia
#             code              client          product           date_time  \
# 56   HTR-7986846      Jose Gutierrez      Smart Watch 2020-04-09 00:46:16
# 106  ABu-6646715      Christina Ruiz  Wireless Router 2024-05-15 12:50:08
# 277  CrB-8267767        Gregg Barker              SSD 2023-09-05 17:55:58
# 382  Spf-8588187  Christopher Brooks    Action Camera 2021-03-17 22:49:04
# 530  UMu-9643403     Cheyenne Lucero    Action Camera 2020-02-23 02:56:05
#
#      attention_time                                            comment  \
# 56        58.742645  Notifications are handy, but can be overwhelming.
# 106      114.148341       Admin interface could be more user-friendly.
# 277      126.851717                Reliable and fast storage solution.
# 382        9.424751        Battery drains quickly with continuous use.
# 530       46.505207    Wide-angle lens captures stunning perspectives.
#
#     country      city
# 56    Spain  Valencia
# 106   Spain  Valencia
# 277   Spain  Valencia
# 382   Spain  Valencia
# 530   Spain  Valencia
# Spain Zaragoza
#             code           client          product           date_time  \
# 11   wBN-6261959       Beth Blake       Smart Lock 2022-04-21 18:12:43
# 26   ovm-5409952    Nicolas Smith      Smart Watch 2023-04-04 04:21:32
# 127  mLZ-5255440   Rachel Burgess   Gaming Console 2024-02-16 12:20:19
# 262  roy-0581416   Vincent Walter   Gaming Console 2024-06-17 10:40:20
# 387  Uwb-0136429  Matthew Johnson  Streaming Stick 2022-12-06 19:04:14
#
#      attention_time                                            comment  \
# 11        99.585569          Setup was more complicated than expected.
# 26        18.563691  Notifications are handy, but can be overwhelming.
# 127       41.627328     Quiet operation, even during intense gameplay.
# 262      116.311436     Quiet operation, even during intense gameplay.
# 387       76.772518       Sometimes lags with high-resolution content.
#
#     country      city
# 11    Spain  Zaragoza
# 26    Spain  Zaragoza
# 127   Spain  Zaragoza
# 262   Spain  Zaragoza
# 387   Spain  Zaragoza
# UK Birmingham
#             code              client            product           date_time  \
# 17   VSV-6542221       Veronica Gray                SSD 2022-01-04 13:15:56
# 42   Lgk-1108434     Casey Mccormick            Monitor 2023-01-31 03:12:07
# 88   yCq-1144955         Pamela Gray  Bluetooth Speaker 2022-05-13 03:58:03
# 150  niX-9258210        Tiffany Mann      Graphics Card 2023-11-13 14:56:47
# 157  EAM-0715148  Dominique Ward DDS    Wireless Router 2022-02-04 07:17:47
#
#      attention_time                                  comment country  \
# 17       137.588234      Reliable and fast storage solution.      UK
# 42       148.889133       Great for gaming with low latency.      UK
# 88       131.712811       Water-resistant feature is a plus.      UK
# 150       56.957820  Can handle most games at high settings.      UK
# 835  Ezl-3198318     Barbara Gomez           Tablet 2024-05-08 14:35:23
#
#      attention_time                                            comment  \
# 103      120.150219             Immersive gaming and media experience.
# 175      145.395949               Convenient for quick file transfers.
# 594      103.077400  Durable and waterproof, great for adventure sp...
# 822       17.957264                  Wish it had more storage options.
# 835      134.468125                        Could use more accessories.
#
#     country           city
# 103     USA  San Francisco
# 175     USA  San Francisco
# 594     USA  San Francisco
# 822     USA  San Francisco
# 835     USA  San Francisco
# USA Seattle
#             code          client            product           date_time  \
# 68   HvK-7192312    Pamela Casey      Graphics Card                 NaT
# 193  yUD-2999762  Katherine Chen            Monitor 2021-05-07 04:53:03
# 232  vaB-7447972      Tammy Wolf    USB Flash Drive 2021-04-12 20:44:17
# 326  cJH-3625814   Jeffrey Zhang         Smartphone 2021-04-09 05:24:35
# 611  OtI-7584611    Thomas Banks  Bluetooth Speaker 2023-08-14 23:32:15
#
#      attention_time                                    comment country  \
# 68       106.058759  Pricey, but worth it for the performance.     USA
# 193       44.294787         Great for gaming with low latency.     USA
# 232       70.285048      Small and portable, but easy to lose.     USA
# 326        6.026091          Wish it had more storage options.     USA
# 611       43.645799         Water-resistant feature is a plus.     USA
#
#         city
# 68   Seattle
# 193  Seattle
# 232  Seattle
# 326  Seattle
# 611  Seattle

# %%
# group and aggregate dataframes using groupby() and aggregate()
# grup by country and get the mean, std, min, max  of attention_time
grouped_country_df = call_center_df.groupby('country').agg({'attention_time': ['mean', 'std', np.min, np.nanmax]})
grouped_country_df
# Out:
# /tmp/ipykernel_350011/1679341506.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_country_df = call_center_df.groupby('country').agg({'attention_time': ['mean', 'std', np.min, np.nanmax]})
# /tmp/ipykernel_350011/1679341506.py:3: FutureWarning: The provided callable <function min at 0x7b1bdd98ade0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grouped_country_df = call_center_df.groupby('country').agg({'attention_time': ['mean', 'std', np.min, np.nanmax]})
# /tmp/ipykernel_350011/1679341506.py:3: FutureWarning: The provided callable <function nanmax at 0x7b1bdd3994e0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped_country_df = call_center_df.groupby('country').agg({'attention_time': ['mean', 'std', np.min, np.nanmax]})
#             attention_time
#                       mean        std       min      nanmax
# country
# Australia        77.564133  41.825168  5.002475  149.999597
# Brazil           77.756712  41.852127  5.000688  149.999462
# Canada           77.474514  41.881525  5.001910  149.996124
# China            77.535011  41.908777  5.002371  149.999675
# France           77.659527  41.936573  5.001077  149.998944
# Germany          77.304183  41.765321  5.000390  149.997648
# India            77.575955  41.794698  5.005280  149.995586
# Italy            77.408117  41.829431  5.003875  149.996914
# Japan            77.500571  41.858569  5.000739  149.999943
# Mexico           77.612920  41.829822  5.000968  149.999955
# Russia           77.587339  42.014596  5.000839  149.998996
# South Korea      77.534233  41.851750  5.000916  149.996096
# Spain            77.571777  41.893639  5.000581  149.996864
# UK               77.575929  41.865870  5.002238  149.998754
# USA              77.352924  41.849598  5.000887  149.996222

# %%
# group by country and city and get the mean, std, min, max of attention_time
grouped_country_city_df = call_center_df.groupby(['country', 'city']).agg({'attention_time': ['mean', 'std', np.min, np.nanmax]})
grouped_country_city_df = grouped_country_city_df.dropna()
grouped_country_city_df.to_csv('csv-files/grouped_country_city.csv')
grouped_country_city_df
# Out:
# /tmp/ipykernel_350011/1507011519.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_country_city_df = call_center_df.groupby(['country', 'city']).agg({'attention_time': ['mean', 'std', np.min, np.nanmax]})
# /tmp/ipykernel_350011/1507011519.py:2: FutureWarning: The provided callable <function min at 0x7b1bdd98ade0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grouped_country_city_df = call_center_df.groupby(['country', 'city']).agg({'attention_time': ['mean', 'std', np.min, np.nanmax]})
# /tmp/ipykernel_350011/1507011519.py:2: FutureWarning: The provided callable <function nanmax at 0x7b1bdd3994e0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped_country_city_df = call_center_df.groupby(['country', 'city']).agg({'attention_time': ['mean', 'std', np.min, np.nanmax]})
#                         attention_time
#                                   mean        std       min      nanmax
# country   city
# Australia Adelaide           77.709053  41.633533  5.005949  149.983077
#           Brisbane           77.662205  42.006778  5.012611  149.994752
#           Canberra           76.959055  41.991513  5.008690  149.996272
#           Melbourne          77.809943  41.732739  5.026245  149.991688
#           Perth              77.996317  41.843446  5.023507  149.940369
# ...                                ...        ...       ...         ...
# USA       Los Angeles        77.425662  41.674721  5.002356  149.980056
#           Miami              77.615529  41.591648  5.006401  149.984026
#           New York           77.599644  42.025886  5.000887  149.976766
#           San Francisco      77.381475  41.738286  5.019476  149.982310
#           Seattle            77.762297  41.958075  5.006975  149.980573
#
# [91 rows x 4 columns]

# %%
grouped_country_city_df = grouped_country_city_df.reset_index()
grouped_country_city_df.head()
# Out:
#      country       city attention_time
#                                   mean        std       min      nanmax
# 0  Australia   Adelaide      77.709053  41.633533  5.005949  149.983077
# 1  Australia   Brisbane      77.662205  42.006778  5.012611  149.994752
# 2  Australia   Canberra      76.959055  41.991513  5.008690  149.996272
# 3  Australia  Melbourne      77.809943  41.732739  5.026245  149.991688
# 4  Australia      Perth      77.996317  41.843446  5.023507  149.940369

# %%
# group and transform dataframes using groupby() and transform()
call_center_df['attention_time_mean'] = call_center_df.groupby('country')['attention_time'].transform(np.mean)
call_center_df['attention_time_std'] = call_center_df.groupby('country')['attention_time'].transform('std')
call_center_df = call_center_df.sort_values(by='country')
print(call_center_df.shape)
call_center_df.head()
# Out:
# /tmp/ipykernel_350011/1031107858.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   call_center_df['attention_time_mean'] = call_center_df.groupby('country')['attention_time'].transform(np.mean)
# /tmp/ipykernel_350011/1031107858.py:2: FutureWarning: The provided callable <function mean at 0x7b1bdd98b6a0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   call_center_df['attention_time_mean'] = call_center_df.groupby('country')['attention_time'].transform(np.mean)
# /tmp/ipykernel_350011/1031107858.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   call_center_df['attention_time_std'] = call_center_df.groupby('country')['attention_time'].transform('std')
# (1000000, 10)
#                code              client                      product  \
# 999999  XRh-5634243  Christopher Harmon              Streaming Stick
# 70627   BYO-8699106     Richard Watkins  Noise Cancelling Headphones
# 504922  uFw-2994564       Robert Juarez                   Smartphone
# 504923  zyz-1962524       Billy Bradley             Smart Thermostat
# 504934  hkc-4959632       Robert Walker                  Smart Watch
#
#                  date_time  attention_time  \
# 999999 2021-05-25 09:54:38       11.099840
# 70627  2020-09-30 05:59:40       63.467884
# 504922 2020-02-26 15:57:40        5.258973
# 504923 2023-10-23 04:09:19       60.877980
# 504934 2020-02-19 07:38:18       67.007363
#
#                                     comment    country       city  \
# 999999        Turns any TV into a smart TV.  Australia   Canberra
# 70627           Sound quality is top-notch.  Australia   Brisbane
# 504922    Wish it had more storage options.  Australia   Adelaide
# 504923  Saves on heating and cooling costs.  Australia      Perth
# 504934  Tracks fitness activity accurately.  Australia  Melbourne
#
#         attention_time_mean  attention_time_std
# 999999            77.564133           41.825168
# 70627             77.564133           41.825168
# 504922            77.564133           41.825168
# 504923            77.564133           41.825168
# 504934            77.564133           41.825168

# %%
print(call_center_df['attention_time_mean'].unique())
# Out:
# [77.5641334  77.75671188 77.47451364 77.53501086 77.65952717 77.30418293
#  77.57595523 77.40811726 77.50057096 77.61291962 77.58733855 77.53423334
#  77.57177674 77.5759291  77.3529239 ]

# %%
# group and filter dataframes using groupby() and filter()
call_center_df_filtered = call_center_df.groupby('country').filter(lambda x: x['attention_time'].mean() > 77.6)
print(call_center_df_filtered.shape)
print(call_center_df_filtered['attention_time_mean'].unique())
call_center_df_filtered.head()
# Out:
# /tmp/ipykernel_350011/1597456090.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   call_center_df_filtered = call_center_df.groupby('country').filter(lambda x: x['attention_time'].mean() > 77.6)
# (199572, 10)
# [77.75671188 77.65952717 77.61291962]
#                code            client            product           date_time  \
# 324875  MEF-3764563  Mikayla Peterson      Graphics Card 2023-12-01 12:38:19
# 357017  dWa-4153507         Tara Lowe         Smartphone 2020-10-31 00:27:43
# 911099  bmB-3623946        Traci Snow   Desktop Computer 2023-03-28 18:56:43
# 357004  yzW-1913985   Kimberly Sutton  Bluetooth Speaker 2021-02-09 17:06:23
# 333155  Srj-1131939      Robert Lewis             Tablet 2020-05-19 14:11:58
#
#         attention_time                                  comment country  \
# 324875       57.773991          Runs cool and quiet under load.  Brazil
# 357017       36.069222        Wish it had more storage options.  Brazil
# 911099       72.484660                 Takes up a lot of space.  Brazil
# 357004       85.606281       Water-resistant feature is a plus.  Brazil
# 333155       44.727984  Great for reading and streaming videos.  Brazil
#
#                   city  attention_time_mean  attention_time_std
# 324875        Salvador            77.756712           41.852127
# 357017  Rio de Janeiro            77.756712           41.852127
# 911099        Salvador            77.756712           41.852127
# 357004       São Paulo            77.756712           41.852127
# 333155  Belo Horizonte            77.756712           41.852127

# %%
# pivot dataframes using pivot_table()
def create_category(x):
    if x > 120:
        return 'Too Bad'
    elif x > 60:
        return 'Bad'
    elif x > 20:
        return 'Medium'
    else:
        return 'Acceptable'

call_center_df['attention_category'] = call_center_df['attention_time'].apply(lambda x: create_category(x))
call_center_df.to_csv('csv-files/call_center_data.csv', index=False)
call_center_df.pivot_table(values='attention_time', index='country', columns='attention_category', aggfunc=['mean', 'min', 'max'], observed=False).head()
# Out:
#                          mean                                          min  \
# attention_category Acceptable        Bad     Medium     Too Bad Acceptable
# country
# Australia           12.522477  89.954171  40.200469  134.997447   5.002475
# Brazil              12.522218  89.997970  39.992445  134.959573   5.000688
# Canada              12.595325  90.104672  40.030873  135.007696   5.001910
# China               12.599466  89.988982  40.081815  135.117533   5.002371
# France              12.562566  90.026974  39.909190  134.905416   5.001077
#
#                                                             max              \
# attention_category        Bad     Medium     Too Bad Acceptable         Bad
# country
# Australia           60.003472  20.001165  120.001180  19.998346  119.997908
# Brazil              60.000151  20.002189  120.003021  19.999621  119.998658
# Canada              60.001768  20.000494  120.003948  19.999028  119.999962
# China               60.001863  20.000859  120.001723  19.999311  119.997419
# France              60.000012  20.007444  120.005430  19.999040  119.998133
#
#
# attention_category     Medium     Too Bad
# country
# Australia           59.999344  149.999597
# Brazil              59.996379  149.999462
# Canada              59.996309  149.996124
# China               59.997002  149.999675
# France              59.994651  149.998944

# %% [markdown]
# ## Advanced Transformations

# %%
# making transformations using apply()
def get_region(country):
    if country in ['Brazil']:
        return 'South America'
    elif country in ['USA', 'Canada', 'Mexico']:
        return 'North America'
    elif country in ['Spain', 'France', 'UK', 'Germany', 'Italy']:
        return 'Europe'
    elif country in ['China', 'South Korea', 'India', 'Japan']:
        return 'Asia'
    elif country in ['Russia']:
        return 'Asia/Europe'
    elif country in ['Australia']:
        return 'Oceania'
    else:
        return 'NA'

call_center_df['region'] = call_center_df['country'].apply(lambda x: get_region(x))
call_center_df.head()
# Out:
#                code              client                      product  \
# 999999  XRh-5634243  Christopher Harmon              Streaming Stick
# 70627   BYO-8699106     Richard Watkins  Noise Cancelling Headphones
# 504922  uFw-2994564       Robert Juarez                   Smartphone
# 504923  zyz-1962524       Billy Bradley             Smart Thermostat
# 504934  hkc-4959632       Robert Walker                  Smart Watch
#
#                  date_time  attention_time  \
# 999999 2021-05-25 09:54:38       11.099840
# 70627  2020-09-30 05:59:40       63.467884
# 504922 2020-02-26 15:57:40        5.258973
# 504923 2023-10-23 04:09:19       60.877980
# 504934 2020-02-19 07:38:18       67.007363
#
#                                     comment    country       city  \
# 999999        Turns any TV into a smart TV.  Australia   Canberra
# 70627           Sound quality is top-notch.  Australia   Brisbane
# 504922    Wish it had more storage options.  Australia   Adelaide
# 504923  Saves on heating and cooling costs.  Australia      Perth
# 504934  Tracks fitness activity accurately.  Australia  Melbourne
#
#         attention_time_mean  attention_time_std attention_category   region
# 999999            77.564133           41.825168         Acceptable  Oceania
# 70627             77.564133           41.825168                Bad  Oceania
# 504922            77.564133           41.825168         Acceptable  Oceania
# 504923            77.564133           41.825168                Bad  Oceania
# 504934            77.564133           41.825168                Bad  Oceania

# %%
# making transformations using chain transformations
# Assuming call_center_df is your DataFrame and get_region is a predefined function

transformed_df = (
    call_center_df
    .assign(
        attention_time=lambda x: x['attention_time'].fillna(x['attention_time'].mean()),
        city=lambda x: x['city'].astype(str).fillna('non-registered'),
        client=lambda x: x['client'].str.capitalize(),
        outlier=lambda x: (np.abs(x['attention_time_mean'] - x['attention_time']) >\
                           np.abs(x['attention_time_mean'] - x['attention_time_std'])).astype(int)
    )
    .dropna()
    .assign(region=lambda x: x['country'].apply(get_region).str.upper())
    .set_index('code')
    .round({'attention_time': 3})
    .rename(columns={'client': 'client_name'})
)

transformed_df.head()
# Out:
#                     client_name                      product  \
# code
# XRh-5634243  Christopher harmon              Streaming Stick
# BYO-8699106     Richard watkins  Noise Cancelling Headphones
# uFw-2994564       Robert juarez                   Smartphone
# zyz-1962524       Billy bradley             Smart Thermostat
# hkc-4959632       Robert walker                  Smart Watch
#
#                       date_time  attention_time  \
# code
# XRh-5634243 2021-05-25 09:54:38          11.100
# BYO-8699106 2020-09-30 05:59:40          63.468
# uFw-2994564 2020-02-26 15:57:40           5.259
# zyz-1962524 2023-10-23 04:09:19          60.878
# hkc-4959632 2020-02-19 07:38:18          67.007
#
#                                          comment    country       city  \
# code
# XRh-5634243        Turns any TV into a smart TV.  Australia   Canberra
# BYO-8699106          Sound quality is top-notch.  Australia   Brisbane
# uFw-2994564    Wish it had more storage options.  Australia   Adelaide
# zyz-1962524  Saves on heating and cooling costs.  Australia      Perth
# hkc-4959632  Tracks fitness activity accurately.  Australia  Melbourne
#
#              attention_time_mean  attention_time_std attention_category  \
# code
# XRh-5634243            77.564133           41.825168         Acceptable
# BYO-8699106            77.564133           41.825168                Bad
# uFw-2994564            77.564133           41.825168         Acceptable
# zyz-1962524            77.564133           41.825168                Bad
# hkc-4959632            77.564133           41.825168                Bad
#
#               region  outlier
# code
# XRh-5634243  OCEANIA        1
# BYO-8699106  OCEANIA        0
# uFw-2994564  OCEANIA        1
# zyz-1962524  OCEANIA        0
# hkc-4959632  OCEANIA        0

# %% [markdown]
# ## Statistical Testing

# %%
# making a t-test with pandas and scipy
# t-test is a statistical test that is used to compare the means of two groups
from scipy.stats import ttest_ind

group1 = call_center_df['group1_scores']
group2 = call_center_df['group2_scores']

t_stat, p_value = ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.9/envs/data_science_course/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group1_scores'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 5
#       1 # making a t-test with pandas and scipy
#       2 # t-test is a statistical test that is used to compare the means of two groups
#       3 from scipy.stats import ttest_ind
# ----> 5 group1 = call_center_df['group1_scores']
#       6 group2 = call_center_df['group2_scores']
#       8 t_stat, p_value = ttest_ind(group1, group2)
#
# File ~/.pyenv/versions/3.11.9/envs/data_science_course/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/.pyenv/versions/3.11.9/envs/data_science_course/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'group1_scores'

# %%
# making an ANOVA test with pandas and scipy
# ANOVA test is a statistical test that is used to compare the means of three or more groups
from scipy.stats import f_oneway

group1 = call_center_df[call_center_df['group_column'] == 'Group1']['scores_column']
group2 = call_center_df[call_center_df['group_column'] == 'Group2']['scores_column']
group3 = call_center_df[call_center_df['group_column'] == 'Group3']['scores_column']

f_stat, p_value = f_oneway(group1, group2, group3)  
print(f"F-statistic: {f_stat}, P-value: {p_value}")

# %%
# making a chi-square test with pandas and scipy
# chi-square test is a statistical test that is used to compare the frequency of two or more groups
from scipy.stats import chi2_contingency

call_center_df['column1'] = call_center_df['column1'].astype('category')
call_center_df['column2'] = call_center_df['column2'].astype('category')

contingency_table = pd.crosstab(call_center_df['column1'], call_center_df['column2'])
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %%
# making a correlation validation with pandas 
# correlation is a statistical test that is used to measure the relationship between two variables
call_center_df.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # making a correlation validation with pandas
#       2 # correlation is a statistical test that is used to measure the relationship between two variables
# ----> 3 call_center_df.corr()
#
# NameError: name 'call_center_df' is not defined

# %%
# p-hacking example

# %%
# p-hacking example with multiple testing

# %%
# p-value example

# %%
# p-value correction with Bonferroni
