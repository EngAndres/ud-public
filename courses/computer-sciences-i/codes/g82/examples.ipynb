# %% [markdown]
# # Euclidean GCD
#
# This is an example of the __Euclidean Algorithm__ for this _course_.

# %%
def euclidean_test(a: int, b: int) -> int:
    """
    This is a function to implement the classical euclidean algorithm
    to calculate the GCD.
    A should greater than B.

    Args:
        a(int): First number, should be greater than b
        b(int): Second number

    Returns:
        An integer with the GCD for the parameters provided.
    """
    if a <= b:
        a, b = b, a

    while b != 0:
        r = a % b
        a, b = b, r
    return a

result = euclidean_test(90, 60)
print(result)

# %%
def euclidean_test_recursive(a: int, b: int) -> int:
    """
    This is a function to implement the classical euclidean algorithm
    to calculate the GCD.

    Args:
        a(int): First number, should be greater than b
        b(int): Second number

    Returns:
        An integer with the GCD for the parameters provided.
    """
    if b == 0:
        return a
    else:
        return euclidean_test_recursive(b, a % b)

print(euclidean_test_recursive(90, 60))

# %% [markdown]
# # Babylian Method for Square Root

# %%
def square_root(s: int) -> float:
    """
    This method calculates a square root of an integer number based
    on the babylonean numeric method to approximate the root.

    Args:
        s(int): Integer as base to calculate the square root

    Returns:
        A float with the square root.
    """
    DIFF = 0.001
    x = s / 2

    while True:
        x_next = (1 / 2) * (x + (s / x))
        diff_x = abs(x - x_next)
        x = x_next
        if diff_x < DIFF:
            break
    return x

print(square_root(234123456789567678934567))

# %% [markdown]
# # FIND MAXIMUM IN AN ARRAY

# %%
def find_maximum(a: list) -> int:
    """
    This method traverses an array and return the maximum item value.
    If the array is empty, and error message is returned.

    Args:
        a(list[int]): Array to be traversed

    Returns:
        An integer with the maximum value in the array
    """
    n = len(a)
    if n == 0:
        raise ValueError("Empty array is not valid.")
    
    max = a[0]
    for i in range(1, n):
        if a[i] > max:
            max = a[i]
    return max

print(max([11,13,4,13,5,6,6,13,4,2,8,4,3,9,13]))

# %% [markdown]
# # Mathematical Notation

# %% [markdown]
# ## Example 1

# %%
n = 5

# calculate sum
sum = 0
for i in range(1, n + 1):
    sum += i**2

# validation
formula = (n * (n + 1) * ((2 * n) + 1)) / 6

if sum == formula:
    print("Validado")
else:
    print("Error")

# %% [markdown]
# ## Example 2

# %%
def factorial(n):
    result = 1
    for i in range(i, n + 1):
        result *= i 
    return result

def factorial_recursive(n):
    if n == 0:
        return 1
    else:
        return n * factorial_recursive(n - 1)

x = int(input("Ingrese el valor de x:"))
result = 1
term = 1
n = 1
DIFF = 0.001

while abs(term) > DIFF:
    term = (x ** n) / factorial(n)
    result += term
    n += 1

print(f'El resultado de la operación eˆ{x} es: { round(result, 5)}')

# %% [markdown]
# ## Decision Tree Example

# %%
def cast_num_to_letter_grade(score: int) -> str:
    if 0 <= score <= 100:
        grade = None
        if score >= 90:
            grade = 'A'
        elif score >= 80:
            grade = 'B'
        elif score >= 70:
            grade = 'C'
        elif score >= 60:
            grade = 'D'
        else:
            grade = 'F'
        return grade
    else:
        raise ValueError("Score UD is not in a valid range.")
    
print(cast_num_to_letter_grade(12))
print(cast_num_to_letter_grade(5))
print(cast_num_to_letter_grade(82))
print(cast_num_to_letter_grade(96))
print(cast_num_to_letter_grade(112))

# %% [markdown]
# ## Find Minimum Coins for Change

# %%
def get_coins_change(n: int, denominations: list) -> list:
    denominations = sorted(denominations, reverse=True)
    result = []
    for d in denominations:
        if d <= n:
            coins = n // d
            n = n % d
            result.append((d, coins))
    return result

denominations = [50, 1000, 500, 100, 200]
print(get_coins_change(29850, denominations))

# %% [markdown]
# ## Knapsack Problem (0/1)

# %%
# items -> weigth, value, name
items = [(5,6,'Item 1'), 
         (58,75,'Item 2'),
         (54,9,'Item 3'),
         (32,56,'Item 4'),
         (67,34,'Item 5')]

def division(item):
    return item[1] / item[0]

# %%
def knapsack(capacity, items):
    items = sorted(items, key=lambda item:item[1] / item[0], reverse=True)
    result = []
    for item in items:
        if item[0] <= capacity:
            result.append(item)
            capacity -= item[0]
    print(f'La maleta tiene {len(result)} con un valor de\
          { sum( [item[1] for item in result] ) }')
    return result

print(knapsack(150, items))

# %% [markdown]
# ## Queens

# %%
data = input()
while data != '0 0 0 0':
    x1, y1, x2, y2 = map(int, data.split())
    result = 2
    if x1 == x2 and y1 == y2:
        result = 0
    elif (x1 == x2) or (y1 == y2) or (abs(x1 - x2) == abs(y1 - y2)):
        result = 1
    print(result)
    data = input()

# %% [markdown]
# ## Optical Reader

# %%
n = int(input())
grades = ['A', 'B', 'C', 'D', 'E']
while n != 0:
    for sheet in range(n):
        answers = list( map(int, input().split()) )
        response = '*'
        found = False
        for i, answer in enumerate(answers):
            if answer <= 127:
                if not found:
                    found = True
                    response = grades[i]
                else:
                    response = '*' # double mark
                    break
        print(response)

    n = int(input())

# %% [markdown]
# ## 3D Virtual Museum

# %%
while True:
    try:
        n, m = map(int, input().split())
    except:
        break
    models = sorted( list( map(int, input().split()) ), reverse = True)
    print( sum( models[:m] ) )

# %% [markdown]
# ## Brutal Force - Cracking Password

# %%
def get_possibilities(character_set: list, lenght: int, current: str = ""):
    if lenght == 1: # base case
        return [current + c for c in character_set]
    else:
        result = []
        for c in character_set:
            result.extend( get_possibilities(character_set, lenght - 1, current + c) )
        return result

# %%
def get_password(character_set: list, password: str, max_length: int) -> str:
    result = None
    for length in range(1, int(max_length) + 1):
        possibilities = get_possibilities(character_set, length)
        for candidate in possibilities:
            if candidate == password:
                print("Found")
                result = candidate
    return result
            
character_set = list('abcdefghijklmnopqrstuvwxyz')
max_ = 6
password = 'zefhuj'
get_password(character_set, password, max_)

# %%
character_set = list('abcdefghijklmnopqrstuvwxyz')
print(get_possibilities(character_set, 4))

# %% [markdown]
# ## The Experiments

# %%
experiments = int(input())
cobaias = {'C': 0, 'R': 0, 'S': 0}

for _ in range(experiments):
    amount, animal = input().split()
    cobaias[animal] += int(amount)

total = sum( cobaias.values() )
coelhos = cobaias['C']
ratos = cobaias['R']
sapos = cobaias['S']

result = f"Total: {total} cobaias\n\
Total de coelhos: {coelhos}\n\
Total de ratos: {ratos}\n\
Total de sapos: {sapos}\n\
Percentual de coelhos: { '%.2f' % round((coelhos / total) * 100, 2) } %\n\
Percentual de ratos: { '%.2f' % round((ratos / total) * 100, 2) } %\n\
Percentual de sapos: { '%.2f' % round((sapos / total) * 100, 2) } %"
print(result)

# %% [markdown]
# ## N-Queens Problem

# %%
def is_safe(board: list, n: int, row: int, col: int) -> bool:
    result = True
    for prev_row in range(row):
        # same column
        if board[prev_row][col] == 'Q':
            result = False
        # same diagonal
        delta = abs(row - prev_row)
        if (col - delta >= 0 and board[prev_row][col - delta] == 'Q') or \
            (col + delta < n and board[prev_row][col + delta] == 'Q'):
            result = False
    return result

# %%
def solve_n_queens(board: list, row: int, n: int):
    if row == n:
        return board # :)
    if row >= len(board):
        board.append(['' for _ in range(n)]) 
    for col in range(n):
        if is_safe(board, n, row, col):
            board[row][col] = 'Q'
            result = solve_n_queens(board, row + 1, n)
            if result is not None:
                return result
            board[row][col] = '' # backtrack
    return None # no column is a solution

# %%
print( solve_n_queens([], 0, 4) )

# %% [markdown]
# ## Linear Search Basic

# %%
from typing import Any

def linear_search(a: list, x: Any) -> int:
    """This function represents the behavior of a linear search
    making a iterator over a set of data.
    
    Args:
        a(list): Set of elemnts
        x(Any): Element to be searched

    Returns:
        An integer number with the index where x appears. If not, 
        -1 is returned as a logic mark.
    """
    index = -1
    for i, item in enumerate(a):
        if item == x:
            index = i
            break
    return index

print( linear_search([76,897,23,3,2,2,2,2,5.3], 5) )

# %% [markdown]
# ## Phone Directory

# %%
phone_directory = [
    {
        'name': "Brayan",
        'number': 12345
    },
    {
        'name': "Daniel",
        'number': 54321,
    },
    {
        'name': "Salome",
        'number': 45667,
    },
    {
        'name': "Fabian",
        'number': 86547,
    },
    {
        'name': "Lucero",
        'number': 98765,
    }
]

# %%
def phone_directory_search(directory: dict, name: str) -> int:
    """This function makes a linear search over a phone directory
    based on the name of the person and returning the respective
    phone number.
    
    Args:
        directory(dict): The phone directory of the town
        name(str): The criterial of the search
    
    Returns:
        The phone number of the person if it is found.
    """
    result = None
    for person in directory:
        if person['name'] == name:
            result = person['number']
            break
    return result

# %%
name = 'Fabian'
print( phone_directory_search(phone_directory, name) )

# %% [markdown]
# ## Binary Search

# %%
from typing import Any

def binary_search(a: list, x: Any, low: int, high: int) -> int:
    """This function represents thew behavior of a typical
    binary search using a loop.

    Args:
        a(list): Set of elements
        x(Any): Element to be searched 
        low(int): Lower index in the search space
        high(int): Upper index in the search space
    
    Returns:
        An integer with the index with the element is found.
        If not found, -1 is returned as a logical mark.
    """
    result = -1
    while low <= high:
        print(f'{low} --- {high}')
        mid = (low + high) // 2
        if a[mid] == x:
            result = mid
            break
        elif a[mid] < x:
            low = mid + 1
        else:
            high = mid - 1
    return result

# %%
a = [i for i in range(1, 1001)]
x = 210
print( binary_search(a, x, 0, len(a) - 1) )

# %% [markdown]
# ## Library UD System

# %%
catalog = [
    {
        'isbn': 1423,
        'name': 'Introduction to Algorithms - Cormen',
        'section': 'Computer Science',
        'closet': '2A',
        'level': 1
    },
    {
        'isbn': 9464,
        'name': 'Effective Java - Bloch',
        'section': 'Programming',
        'closet': '2B',
        'level': 2
    },
    {
        'isbn': 5434,
        'name': 'JavaScript: The Good Parts - Crockford',
        'section': 'Web Development',
        'closet': '3A',
        'level': 1
    },
    {
        'isbn': 6132,
        'name': 'The Pragmatic Programmer - Hunt & Thomas',
        'section': 'Software Engineering',
        'closet': '1A',
        'level': 2
    },
    {
        'isbn': 3218,
        'name': 'Python for Data Analysis - McKinney',
        'section': 'Data Science',
        'closet': '4A',
        'level': 2
    },
    {
        'isbn': 6539,
        'name': 'Hands-On Machine Learning - Géron',
        'section': 'Machine Learning',
        'closet': '4B',
        'level': 3
    },
    {
        'isbn': 7654,
        'name': 'The C Programming Language - Kernighan & Ritchie',
        'section': 'Programming',
        'closet': '2C',
        'level': 1
    },
    {
        'isbn': 3421,
        'name': 'Operating System Concepts - Silberschatz',
        'section': 'Operating Systems',
        'closet': '3B',
        'level': 2
    },
    {
        'isbn': 1234,
        'name': 'Design Patterns - Gang of Four',
        'section': 'Software Engineering',
        'closet': '1B',
        'level': 3
    },
    {
        'isbn': 8764,
        'name': 'Clean Code - Martin',
        'section': 'Software Engineering',
        'closet': '1C',
        'level': 1
    }
]

# %%
def book_search(catalog: list, isbn: int) -> int:
    """This function is used to find a book information
    into the library based on the ISBN.

    Args:
        catalog(list): Set of books
        isbn(int): Book to be searched 
    
    Returns:
        An integer with the index where the book is found.
        If not found, -1 is returned as a logical mark.
    """
    result = "Book not found"
    low = 0
    high = len(catalog) - 1
    while low <= high:
        mid = (low + high) // 2
        if catalog[mid]['isbn'] == isbn:
            result = catalog[mid]
            break
        elif catalog[mid]['isbn'] < isbn:
            low = mid + 1
        else:
            high = mid - 1
    return result

# %%
#def lambda(book):
#    return book['isbn']

catalog = sorted(catalog, key=lambda book:book['isbn'])
print(catalog)
isbn = 1234
print( book_search(catalog, isbn) )

# %% [markdown]
# ## Interpolation Search

# %%
from typing import Any

def interpolation_search(a: list, x: Any, low: int, high: int) -> int:
    """This function represents thew behavior of a typical
    interpolation search using a loop.

    Args:
        a(list): Set of elements
        x(Any): Element to be searched 
        low(int): Lower index in the search space
        high(int): Upper index in the search space
    
    Returns:
        An integer with the index with the element is found.
        If not found, -1 is returned as a logical mark.
    """
    result = -1
    while low <= high and x >= a[low] and x <= a[high]:
        print(f'{low} --- {high}')
        pos = int(low + ( ((x - a[low]) / (a[high] - a[low])) * (high - low) ))

        if a[pos] == x:
            result = pos
            break
        elif a[pos] < x:
            low = pos + 1
        else:
            high = pos - 1
    return result

# %%
print( interpolation_search(a, x, 0, len(a)-1))

# %% [markdown]
# ## Bubblesort

# %%
def bubble_sort(a: list) -> list:
    n = len(a)
    for i in range(n -1):
        for j in range(n - 1 - i):
            if a[j] > a[j + 1]:
                # swap
                a[j], a[j + 1] = a[j + 1], a[j]
    return a

# %%
a = [4,6,7,3,5,9,8,4,3]
print( bubble_sort(a.copy()) )

# %% [markdown]
# ## Selection Sort

# %%
def selection_sort(a: list) -> list:
    n = len(a)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n): 
            if a[j] < a[min_index]:
                min_index =j
        a[i], a[min_index] = a[min_index],  a[i]
    return a

# %%
print( selection_sort(a.copy()) )

# %% [markdown]
# ## Student Grades Enrollment Schedule

# %%
students = [
    {  
        'name': "Alice",
        'gpa': 3.8
    },
    {  
        'name': "Bob",
        'gpa': 2.5
    },
    {  
        'name': "Charlie",
        'gpa': 3.9
    },
    {  
        'name': "Diana",
        'gpa': 2.1
    },
    {  
        'name': "Eve",
        'gpa': 3.7
    }
]

# %%
def organized_by_gpa_by_bubble(students: list) -> list:
    n = len(students)
    for i in range(n -1):
        for j in range(n - 1 - i):
            if students[j]['gpa'] < students[j + 1]['gpa']:
                students[j], students[j + 1] = students[j + 1], students[j]
    return students

# %%
def organized_by_gpa_by_selection(a: list) -> list:
    n = len(a)
    for i in range(n - 1):
        max_index = i
        for j in range(i + 1, n): 
            if a[j]['gpa'] > a[max_index]['gpa']:
                max_index = j
        a[i], a[max_index] = a[max_index],  a[i]
    return a

# %%
print( organized_by_gpa_by_bubble( students.copy() ) )

# %%
print( organized_by_gpa_by_selection( students.copy() ) )

# %% [markdown]
# ## Insertion Sort

# %%
def insertion_sort(a: list) -> list:
    n = len(a)
    for i in range(1, n):
        value = a[i]
        j = i - 1
        while j >= 0 and a[j] > value:
            a[j + 1] = a[j]
            j -= 1
        a[j + 1] = value
    return a

# %%
from random import randint
a = [randint(1,100) for _ in range(10)]
print(a)
print( insertion_sort(a) )

# %% [markdown]
# ## Challenge

# %%
from random import randint
dataset = [int(''.join(map(str, 
                           [2026] + [randint(1, 9) for __ in range(7)]
                        )
                    )
            ) 
           for _ in range(100000)]
print(dataset)
# Out:
# [20266589814, 20263711336, 20261518927, 20269786965, 20261457481, 20266194392, 20262817233, 20269748186, 20267358643, 20262725636, 20265545612, 20269492119, 20263639821, 20265272594, 20264587568, 20263411524, 20262434993, 20269424541, 20264277496, 20262811283, 20261951517, 20262572264, 20262732689, 20265932287, 20269253247, 20262614328, 20262812858, 20265188768, 20267661246, 20263611929, 20261745727, 20262139569, 20262346727, 20269546484, 20264293289, 20269829698, 20263225215, 20268955957, 20261762941, 20264784712, 20266652369, 20263336414, 20268147561, 20267221443, 20268767619, 20263567964, 20262727912, 20262864443, 20266158693, 20263715584, 20267389395, 20265161878, 20269947132, 20264611799, 20269948299, 20268426293, 20266397572, 20265565875, 20262666743, 20261319671, 20267811633, 20266248252, 20265681847, 20264777354, 20261826763, 20263432195, 20266298577, 20261141791, 20269656126, 20262273786, 20269737584, 20267697161, 20264943378, 20261922265, 20262598711, 20261571471, 20269619784, 20263315477, 20267879442, 20261743252, 20269249478, 20262994868, 20267267489, 20265365953, 20261435434, 20264545589, 20269858976, 20267684471, 20266969974, 20269962137, 20262855179, 20261177733, 20267581341, 20263692614, 20268664194, 20268461148, 20269531732, 20261136726, 20263669838, 20265528464, 20269952655, 20263617666, 20263652246, 20261839685, 20262682469, 20264
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 15
#      11 print("Insertion Time:", end_insertion - start_insertion)
#      14 start_selection = time()
# ---> 15 a = selection_sort(dataset.copy())
#      16 end_selection = time()
#      17 print("Selection Time:", end_selection - start_selection)
#
# Cell In[15], line 6, in selection_sort(a)
#       4 min_index = i
#       5 for j in range(i + 1, n):
# ----> 6     if a[j] < a[min_index]:
#       7         min_index =j
#       8 a[i], a[min_index] = a[min_index],  a[i]
#
# KeyboardInterrupt:

# %% [markdown]
# # QuickSort

# %%
from random import randint
a = [randint(1,10000) for _ in range(2000)]
print(a)
# Out:
# [424, 4516, 8577, 9258, 8003, 9192, 5734, 2966, 1848, 8052, 7174, 7839, 6366, 9780, 8655, 3551, 1713, 6110, 2512, 1611, 9217, 8550, 9929, 165, 3443, 2436, 4929, 7098, 277, 2932, 9049, 2391, 5746, 2919, 4951, 3434, 9407, 5639, 7093, 3624, 5903, 4654, 6115, 6865, 7062, 1393, 4703, 7728, 6153, 1044, 4819, 7068, 3106, 352, 8565, 5337, 8347, 9385, 4261, 448, 8129, 3089, 5090, 5491, 2760, 3712, 588, 2162, 546, 3045, 7174, 4492, 9011, 9568, 6408, 5774, 5550, 4465, 1081, 2923, 886, 2347, 4193, 6909, 2842, 5716, 5454, 5576, 4373, 3106, 9249, 582, 9166, 8051, 9810, 2827, 3992, 3281, 5689, 9997, 6015, 7639, 9681, 2016, 8636, 8427, 9146, 5466, 5475, 5278, 8732, 5910, 230, 2820, 5813, 1041, 7277, 298, 3436, 1567, 1984, 787, 6816, 3107, 6334, 4578, 8817, 687, 575, 9206, 8606, 9731, 4780, 2886, 4090, 2687, 4594, 3082, 3794, 5841, 1890, 1572, 541, 4136, 9226, 3583, 5532, 2390, 7380, 3559, 5100, 9334, 9909, 4901, 7830, 7233, 8759, 9560, 8308, 3793, 3162, 96, 7867, 4171, 599, 9126, 4322, 7649, 7088, 422, 3426, 2132, 2693, 382, 6232, 6272, 4118, 4534, 593, 2185, 3106, 8301, 927, 7855, 2101, 9074, 6398, 1192, 9533, 9314, 458, 7021, 6929, 1865, 5657, 929, 5254, 9134, 8144, 438, 3708, 1647, 8443, 576, 2371, 3440, 2828, 778, 2936, 422, 7516, 5794, 7309, 1732, 4833, 9134, 5733, 8728, 4034, 140, 6705, 1259, 756, 7521, 8769, 5761, 303, 9636, 7494, 622, 6119, 6229, 6096, 1678, 3264, 6627, 7067, 8035, 169, 7360, 5704, 9769, 2180, 44, 994, 5011, 7296, 9018, 4475, 1510, 9070, 7642, 9836, 5254, 7018, 6846, 4938, 2540, 1263, 3818, 3837, 7841, 7956, 5995, 3411, 3040, 3736, 1329, 319, 2603, 699, 4450, 877, 1899, 5974, 1242, 1487, 5844, 168, 9063, 9438, 6255, 1145, 1259, 445, 7314, 7645, 6818, 5117, 2098, 3620, 6149, 3927, 6423, 4734, 209, 5042, 4026, 5482, 185, 2835, 1246, 8414, 1567, 4059, 8972, 8809, 5188, 3748, 3148, 4254, 6833, 5824, 8225, 9917, 5916, 3095, 5564, 2144, 486, 951, 7997, 3276, 4238
    return pivot, left_a, right_a

def quick_sort(a: list) -> list:
    if len(a) == 1:
        return a
    else:
        pivot, left_a, right_a = partition(a)
        if len(left_a) > 0:
            left_a = quick_sort(left_a)
        if len(right_a) > 0:
            right_a = quick_sort(right_a)
        return left_a + [pivot] + right_a

# %%
print(a)
print( quick_sort(a) )
# Out:
# [7143, 5974, 2022, 3093, 9042, 9534, 4826, 1008, 6020, 7736, 3293, 7677, 6865, 8144, 5870, 350, 3112, 9255, 737, 2474, 5547, 9424, 1978, 5768, 938, 1257, 5252, 7765, 9352, 5063, 1138, 3912, 2382, 3387, 418, 9992, 8449, 9565, 811, 2727, 6043, 356, 161, 8828, 8859, 9989, 8163, 7037, 740, 2396, 4413, 6831, 802, 383, 1305, 7803, 4877, 1958, 9758, 291, 5665, 7978, 8288, 7633, 7723, 9504, 608, 3036, 8768, 3212, 8664, 7009, 5286, 4527, 3423, 903, 3127, 3677, 9390, 6693, 4533, 7641, 6315, 3569, 4886, 8319, 7529, 5507, 7346, 3544, 6505, 4525, 2061, 2725, 1733, 7401, 6860, 9705, 5902, 3972, 4192, 3181, 842, 4700, 7705, 5343, 6461, 8962, 7683, 3506, 4819, 7221, 1299, 3356, 1152, 133, 6533, 7840, 7292, 6096, 2249, 9609, 160, 6861, 734, 4326, 5293, 2181, 9413, 4432, 7012, 8703, 4757, 9078, 6896, 1951, 9335, 2542, 1457, 1656, 595, 8016, 9332, 9408, 8935, 3677, 6629, 7977, 8252, 8291, 4041, 3445, 3723, 9760, 8920, 6096, 3401, 6810, 1124, 5274, 8208, 1484, 8595, 1159, 7700, 4533, 5655, 5679, 235, 1883, 3716, 4054, 2799, 2767, 6407, 3509, 6991, 1227, 4602, 2377, 5706, 7544, 4393, 5750, 5130, 808, 1382, 276, 8399, 7188, 911, 8042, 2185, 7062, 5581, 2434, 5618, 475, 2715, 9748, 6241, 4928, 169, 5873, 1265, 2362, 977, 8897, 9483, 6427, 6763, 4536, 6013, 3675, 6419, 7130, 1078, 4110, 3157, 5971, 2298, 337, 4094, 3715, 5289, 9995, 5214, 2079, 7674, 329, 4013, 4662, 9279, 5014, 2232, 9391, 2935, 752, 3519, 4907, 7893, 7633, 8495, 7597, 705, 5586, 7816, 93, 6741, 674, 1341, 4746, 9848, 1851, 7761, 4142, 1371, 2895, 8807, 7293, 5360, 4322, 9556, 2264, 8847, 7529, 1167, 7005, 710, 4844, 4182, 9598, 602, 6514, 1466, 7263, 1067, 9568, 3227, 9905, 4887, 3254, 5300, 3475, 3424, 7646, 6193, 2522, 1980, 3603, 6793, 6682, 5296, 6531, 192, 6877, 1846, 700, 6626, 8121, 3420, 4281, 7221, 9670, 2122, 9428, 5992, 8029, 2741, 9454, 4552, 8727, 1372, 3023, 4347, 7102, 9972, 9894, 4320, 4022, 9721, 3796, 9803, 908, 774, 2514, 2858, 751, 2369, 6030, 2932, 8867, 7525, 682, 6788, 601, 1779, 5910, 5612, 7953, 2033, 7304, 6271, 7410, 4591, 9593, 1889, 9
, 2459, 2471, 2474, 2476, 2476, 2476, 2477, 2479, 2493, 2503, 2508, 2514, 2514, 2517, 2522, 2528, 2530, 2536, 2536, 2537, 2538, 2542, 2546, 2549, 2559, 2563, 2563, 2565, 2573, 2579, 2585, 2593, 2605, 2613, 2617, 2620, 2624, 2624, 2626, 2629, 2653, 2656, 2660, 2666, 2672, 2674, 2684, 2703, 2715, 2715, 2718, 2718, 2719, 2719, 2725, 2727, 2728, 2730, 2732, 2732, 2736, 2738, 2741, 2742, 2743, 2748, 2762, 2763, 2767, 2779, 2795, 2799, 2805, 2812, 2818, 2820, 2832, 2841, 2851, 2851, 2854, 2855, 2857, 2858, 2871, 2878, 2895, 2900, 2902, 2916, 2925, 2927, 2930, 2932, 2935, 2958, 2962, 2963, 2970, 2974, 2980, 2984, 2995, 3007, 3010, 3012, 3014, 3023, 3027, 3036, 3037, 3052, 3054, 3054, 3055, 3056, 3059, 3067, 3068, 3078, 3093, 3100, 3112, 3112, 3114, 3127, 3127, 3137, 3157, 3180, 3181, 3184, 3187, 3199, 3203, 3205, 3205, 3208, 3212, 3212, 3216, 3216, 3221, 3223, 3224, 3227, 3237, 3241, 3241, 3242, 3243, 3245, 3247, 3249, 3254, 3256, 3256, 3260, 3267, 3267, 3275, 3278, 3279, 3281, 3288, 3290, 3293, 3294, 3306, 3306, 3312, 3316, 3317, 3323, 3332, 3347, 3355, 3356, 3366, 3369, 3372, 3376, 3387, 3393, 3396, 3401, 3403, 3420, 3421, 3423, 3424, 3438, 3445, 3449, 3451, 3452, 3460, 3475, 3475, 3498, 3502, 3504, 3506, 3507, 3509, 3510, 3519, 3523, 3529, 3531, 3532, 3537, 3537, 3541, 3543, 3544, 3556, 3557, 3563, 356 ...

# %% [markdown]
# # MergeSort

# %%
def merge(left: list, right: list) -> list:
    result = []
    i_left = 0
    i_right = 0
    while i_left < len(left) and i_right < len(right):
        if left[i_left] < right[i_right]:
            result.append(left[i_left])
            i_left += 1
        else:
            result.append(right[i_right])
            i_right += 1
    result.extend(left[i_left:])
    result.extend(right[i_right:])
    return result

# %%
def merge_sort(a: list) -> list:
    if len(a) == 1: 
        return a
    else:
        mid = len(a) // 2
        left = merge_sort(a[:mid])
        right = merge_sort(a[mid:])
        return merge(left, right)

# %%
print(merge_sort(dataset.copy()))
# Out:
# [20261111147, 20261111211, 20261111217, 20261111279, 20261111651, 20261111678, 20261111714, 20261111772, 20261111822, 20261111849, 20261111878, 20261112128, 20261112178, 20261112246, 20261112589, 20261112626, 20261112739, 20261112765, 20261112767, 20261112941, 20261112988, 20261113244, 20261113285, 20261113334, 20261113352, 20261113534, 20261113551, 20261113681, 20261113711, 20261113969, 20261113993, 20261114148, 20261114169, 20261114272, 20261114341, 20261114351, 20261114636, 20261114695, 20261114699, 20261114715, 20261114724, 20261114786, 20261114825, 20261114838, 20261114876, 20261114942, 20261115121, 20261115158, 20261115212, 20261115223, 20261115244, 20261115337, 20261115382, 20261115411, 20261115459, 20261115554, 